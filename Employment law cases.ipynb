# %% [markdown]
# # Scraping of information on UK employment law cases
#
# As first attempt at webscraping and using BeautifulSoup, I sought to fulfill a brief a friend of mine hired a data scientist for to complete:
#
# - For all the cases listed on the https://www.gov.uk/employment-tribunal-decisions/ website, retrieve case number, country, date, parties involved and their legal representation, and the outcome of the case.
# - There are approximately 1000 pages with 50 cases each on the website.
# - Most information could be found in various chunks of metadata in the page HTML. Only the legal representation was recorded in a case pdf which is available on the page of each case. Unfortunately, the text could not be read straight from the pdf. The pdf needed to be converted to docx before reading.

# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_html_data(url):
    response = requests.get(url, timeout = 5)
    data = BeautifulSoup(response.content, 'html.parser')
    return data

# %%
# retrieves the first webpage with the list of court cases
get_html_data("https://www.gov.uk/employment-tribunal-decisions?page=1")
BeautifulSoup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]--><!--[if gt IE 8]><!--><html lang="en">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." property="og:description"/>
# <meta content="Employment tribunal decisions" property="og:title"/>
# <meta content="https://www.gov.uk/employment-tribunal-decisions" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="GOV.UK" property="og:site_name"/>
# <meta content="Employment tribunal decisions - GOV.UK" name="govuk:base_title"/>
# <meta content="noindex" name="robots"/>
# <meta content="54673" name="govuk:search-result-count"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
# <meta content="true" name="govuk:static-analytics:strip-postcodes"/>
# <meta content="1b5e08c8-ddde-4637-9375-f79e085ba6d5" name="govuk:content-id"/>
# <meta content="finder" name="govuk:schema-name"/>
# <meta content="specialist-publisher" name="govuk:publishing-application"/>
# <meta content="finder" name="govuk:format"/>
# <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." name="description"/>
# <meta content="+SMQCD+4fMPn3ZZCI0bizNj7prYLk+p+2jwjaV0ImAr08AgQr08IaayD7oAgGaTa9u09HwFv8iD9gsyr//yU/A==" name="csrf-token"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta charset="utf-8"/>
# <title>Employment tribunal decisions - GOV.UK</title>
# <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
# <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
# <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
# <meta content="#0b0c0c" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/header-footer-only-ef73612898212d607476ed8b99e91f8114bea610dd6a3347ac10b304b33d7206.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/header-footer-only-ie8-02c83f41ee7cfdfa330b28e4216ed7133e679041435c86df85ed233912718532.css" /><script>var ieVersion = 8;</script><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/header-footer-only-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
# <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js"></script>
# <script>
#       if (GOVUK.globalBarInit) {
#         window.GOVUK.globalBarInit.init()
#       }
#     </script>
# <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
# <link href="https://assets.publishing.service.gov.uk/finder-frontend/application-d8e0b3457bbdd3e6ccfe0d74b8978d2664c170509b0e1c7da8eec80be0ce56ec.css" media="screen" rel="stylesheet"/>
# <link href="https://assets.publishing.service.gov.uk/finder-frontend/print-be4f4422c0e3929d5e90911ea1d3ada170af9fd32dc52c040620a290c7f798b6.css" media="print" rel="stylesheet"/>
# <link href="/employment-tribunal-decisions.atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
# <link href="/api/content/employment-tribunal-decisions" rel="alternate" type="application/json"/>
# <link href="https://www.gov.uk/employment-tribunal-decisions" rel="canonical"/>
# <meta content="finder-frontend" name="govuk:rendering-application"/>
# </head>
# <body class="">
# <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
# <div id="skiplink-container">
# <div>
# <a class="skiplink govuk-link" href="#content">Skip to main content</a>
# </div>
# </div>
# <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
# <div class="gem-c-cookie-banner__wrapper govuk-width-container">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-cookie-banner__message">
# <span class="govuk-heading-m">Tell us whether you accept cookies</span>
# <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
# </div>
# <div class="gem-c-cookie-banner__buttons">
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
# </div>
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
# <p class="gem-c-cookie-banner__confirmation-message">
#       You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#     </p>
# <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
# </div>
# </div>
# <header class="" id="global-header" role="banner">
# <div class="header-wrapper">
# <div class="header-global">
# <div class="header-logo">
# <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
# <span class="govuk-header__logotype">
# <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
# <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17
# <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
# <div class="content govuk-clearfix">
# <label for="site-search-text">Search</label>
# <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
# <input class="submit" type="submit" value="Search"/>
# </div>
# </form>
# </div>
# </div>
# </header>
# <div id="user-satisfaction-survey-container"></div>
# <div id="global-header-bar"></div>
# <!--[if gt IE 7]><!-->
# <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
# <div class="global-bar-message-container">
# <p class="global-bar-message">
# <span class="global-bar-title">The UK has left the EU</span>
# <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
# </p>
# <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
# </div>
# </div>
# <!--<![endif]-->
# <div id="wrapper">
# <main class="finder-frontend-content" id="content">
# <div class="finder-frontend">
# <form action="/employment-tribunal-decisions" class="js-live-search-form" method="get">
# <input name="parent" type="hidden" value=""/>
# <div class="govuk-width-container">
# <div class="gem-c-phase-banner govuk-phase-banner">
# <p class="govuk-phase-banner__content">
# <strong class="govuk-tag govuk-phase-banner__content__tag">beta</strong>
# <span class="govuk-phase-banner__text">This part of GOV.UK is being rebuilt – <a class="govuk-link" href="/help/beta">find out what beta means</a></span>
# </p>
# </div>
# <div class="gem-c-contextual-breadcrumbs">
# <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
# <ol class="govuk-breadcrumbs__list">
# <li aria-current="false" class="govuk-breadcrumbs__list-item">
# <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
# </li>
# </ol>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
# <h1 class="gem-c-title__text">
#     Employment tribunal decisions
#   </h1>
# </div>
# <div class="gem-c-metadata" data-module="gem-toggle">
# <dl data-module="track-click">
# <dt class="gem-c-metadata__term">From:</dt>
# <dd class="gem-c-metadata__definition">
# <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>
# </dd>
# </dl>
# </div>
# </div>
# <div class="govuk-grid-column-two-thirds">
# <div class="metadata-summary">
# <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
# <p>Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.</p>
# <p>If the decision was made before February 2017, contact <a href="https://courttribunalfinder.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a> for cases in England or Wales, or <a href="https://courttribunalfinder.service.gov.uk/courts/glasgow-tribunal-hearing-centre-eagle-building">Glasgow Tribunal Hearing Centre</a> for cases in Scotland.</p>
# <p>Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="govuk-width-container">
# <div class="govuk-grid-row">
# <div aria-label="Employment tribunal decisions" class="govuk-grid-column-one-third" role="search">
# <div class="filter-form">
# <div id="keywords">
# <div class="gem-c-search gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
# <label class="gem-c-search__label" for="finder-keyword-search">
#             Search <span class="govuk-visually-hidden">Employment tribunal decisions</span>
# </label>
# <div class="gem-c-search__item-wrapper">
# <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
# <div class="gem-c-search__item gem-c-search__submit-wrapper">
# <button class="gem-c-search__submit" type="submit">Search</button>
# </div>
# </div>
# </div>
# </div>
# <button class="app-c-button-as-link app-mobile-filters-link js-show-mobile-filters" data-module="track-click" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#         Filter <span class="govuk-visually-hidden"> results</span>
# <span class="js-selected-filter-count"></span>
# </button>
# <div data-module="track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
# <a class="gem-c-skip-link govuk-skip-link" href="#js-results">Skip to results</a>
# </div>
# <div class="facets" data-module="mobile-filters-modal" id="facet-wrapper">
# <div class="facets__box">
# <div class="facets__header">
# <h1 class="gem-c-title__text">Filter</h1>
# <button class="app-c-button-as-link facets__return-link js-close-filters" type="button">
#             Return to results
#           </button>
# </div>
# <div class="facets__content">
# <div class="app-c-option-select" data-input-aria-controls="js-search-results-info" data-module="option-select">
# <h2 class="app-c-option-select__heading js-container-heading">
# <span class="app-c-option-select__title js-container-button" id="option-select-title-country">Country</span>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
# </h2>
# <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
# <div class="app-c-option-select__container-inner js-auto-height-inner">
# <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-0abe2025">
# <fieldset class="govuk-fieldset">
# <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Country</legend>
# <ul class="govuk-checkboxes gem-c-checkboxes__list">
# <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">England and Wales</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">Scotland</label>
# </li>
# </ul>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# <div class="app-c-option-select" data-closed-on-load="true" data-input-aria-controls="js-search-results-info" data-module="option-select">
# <h2 class="app-c-option-select__heading js-container-heading">
# <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">Jurisdiction code</span>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
# </h2>
# <div aria-labelledby="option-select-title-jurisdiction-code" class="app-c-option-select__container js-options-container" id="tribunal_decision_categories" role="group" tabindex="-1">
# <div class="app-c-option-select__container-inner js-auto-height-inner">
# <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-36b163d4">
# <fieldset class="govuk-fieldset">
# <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Jurisdiction code</legend>
# <ul class="govuk-checkboxes gem-c-checkboxes__list">
# <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Age Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-age-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="age-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-age-discrimination">Age Discrimination</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Agency Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-agency-workers" name="tribunal_decision_categories[]" type="checkbox" value="agency-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-agency-workers">Agency Workers</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Blacklisting Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-blacklisting-regulations" name="tribunal_decision_categories[]" type="checkbox" value="blacklisting-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-blacklisting-regulations">Blacklisting Regulations</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Breach of Contract" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-breach-of-contract" name="tribunal_decision_categories[]" type="checkbox" value="breach-of-contract"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-breach-of-contract">Breach of Contract</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Central Arbitration Committee (CAC)" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-central-arbitration-committee-cac" name="tribunal_decision_categories[]" type="checkbox" value="central-arbitration-committee-cac"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-central-arbitration-committee-cac">Central Arbitration Committee (CAC)</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Certification Officer" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-certification-officer" name="tribunal_decision_categories[]" type="checkbox" value="certification-officer"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-certification-officer">Certification Officer</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Contract of Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-contract-of-employment" name="tribunal_decision_categories[]" type="checkbox" value="contract-of-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-contract-of-employment">Contract of Employment</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Disability Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-disability-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="disability-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-disability-discrimination">Disability Discrimination</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Employment Agencies Act 1973" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-employment-agencies-act-1973" name="tribunal_decision_categories[]" type="checkbox" value="employment-agencies-act-1973"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-employment-agencies-act-1973">Employment Agencies Act 1973</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Equal Pay Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-equal-pay-act" name="tribunal_decision_categories[]" type="checkbox" value="equal-pay-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-equal-pay-act">Equal Pay Act</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="European Material" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-european-material" name="tribunal_decision_categories[]" type="checkbox" value="european-material"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-european-material">European Material</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Fixed Term Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-fixed-term-regulations" name="tribunal_decision_categories[]" type="checkbox" value="fixed-term-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-fixed-term-regulations">Fixed Term Regulations</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Flexible Working" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-flexible-working" name="tribunal_decision_categories[]" type="checkbox" value="flexible-working"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-flexible-working">Flexible Working</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Harassment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-harassment" name="tribunal_decision_categories[]" type="checkbox" value="harassment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-harassment">Harassment</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Health &amp; Safety" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-health-safety" name="tribunal_decision_categories[]" type="checkbox" value="health-safety"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-health-safety">Health &amp; Safety</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Human Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-human-rights" name="tribunal_decision_categories[]" type="checkbox" value="human-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-human-rights">Human Rights</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Improvement Notice" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-improvement-notice" name="tribunal_decision_categories[]" type="checkbox" value="improvement-notice"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-improvement-notice">Improvement Notice</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Interim Relief" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-interim-relief" name="tribunal_decision_categories[]" type="checkbox" value="interim-relief"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-interim-relief">Interim Relief</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Jurisdictional Points" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-jurisdictional-points" name="tribunal_decision_categories[]" type="checkbox" value="jurisdictional-points"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-jurisdictional-points">Jurisdictional Points</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Maternity and Pregnancy Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-maternity-and-pregnancy-rights" name="tribunal_decision_categories[]" type="checkbox" value="maternity-and-pregnancy-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-maternity-and-pregnancy-rights">Maternity and Pregnancy Rights</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Minimum Wage" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-minimum-wage" name="tribunal_decision_categories[]" type="checkbox" value="national-minimum-wage"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-minimum-wage">National Minimum Wage</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Security" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-security" name="tribunal_decision_categories[]" type="checkbox" value="national-security"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-security">National Security</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Notice Appeal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-notice-appeal" name="tribunal_decision_categories[]" type="checkbox" value="notice-appeal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-notice-appeal">Notice Appeal</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Parental and Maternity Leave" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-parental-and-maternity-leave" name="tribunal_decision_categories[]" type="checkbox" value="parental-and-maternity-leave"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-parental-and-maternity-leave">Parental and Maternity Leave</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Part Time Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-part-time-workers" name="tribunal_decision_categories[]" type="checkbox" value="part-time-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-part-time-workers">Part Time Workers</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Pension" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-pension" name="tribunal_decision_categories[]" type="checkbox" value="pension"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-pension">Pension</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Practice and Procedure Issues" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-practice-and-procedure-issues" name="tribunal_decision_categories[]" type="checkbox" value="practice-and-procedure-issues"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-practice-and-procedure-issues">Practice and Procedure Issues</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Protective Award" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-protective-award" name="tribunal_decision_categories[]" type="checkbox" value="protective-award"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-protective-award">Protective Award</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Public Interest Disclosure" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-public-interest-disclosure" name="tribunal_decision_categories[]" type="checkbox" value="public-interest-disclosure"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-public-interest-disclosure">Public Interest Disclosure</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Race Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-race-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="race-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-race-discrimination">Race Discrimination</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Redundancy" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-redundancy" name="tribunal_decision_categories[]" type="checkbox" value="redundancy"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-redundancy">Redundancy</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Religion or Belief Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-religion-or-belief-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="religion-or-belief-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-religion-or-belief-discrimination">Religion or Belief Discrimination</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Renumeration" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-renumeration" name="tribunal_decision_categories[]" type="checkbox" value="renumeration"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-renumeration">Renumeration</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reorganisation" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reorganisation" name="tribunal_decision_categories[]" type="checkbox" value="reorganisation"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reorganisation">Reorganisation</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reserved Forces Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reserved-forces-act" name="tribunal_decision_categories[]" type="checkbox" value="reserved-forces-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reserved-forces-act">Reserved Forces Act</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Right To Be Accompanied" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-right-to-be-accompanied" name="tribunal_decision_categories[]" type="checkbox" value="right-to-be-accompanied"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-right-to-be-accompanied">Right To Be Accompanied</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Rights on Insolvency" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-rights-on-insolvency" name="tribunal_decision_categories[]" type="checkbox" value="rights-on-insolvency"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-rights-on-insolvency">Rights on Insolvency</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sex Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sex-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="sex-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sex-discrimination">Sex Discrimination</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sexual Orientation Discrimination/Transexualism" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sexual-orientation-discrimination-transexualism" name="tribunal_decision_categories[]" type="checkbox" value="sexual-orientation-discrimination-transexualism"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sexual-orientation-discrimination-transexualism">Sexual Orientation Discrimination/Transexualism</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Statutory Discipline and Grievance Procedures" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-statutory-discipline-and-grievance-procedures" name="tribunal_decision_categories[]" type="checkbox" value="statutory-discipline-and-grievance-procedures"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-statutory-discipline-and-grievance-procedures">Statutory Discipline and Grievance Procedures</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Tax" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-tax" name="tribunal_decision_categories[]" type="checkbox" value="tax"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-tax">Tax</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Temporary Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-temporary-employment" name="tribunal_decision_categories[]" type="checkbox" value="temporary-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-temporary-employment">Temporary Employment</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Limits" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-limits" name="tribunal_decision_categories[]" type="checkbox" value="time-limits"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-limits">Time Limits</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Off" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-off" name="tribunal_decision_categories[]" type="checkbox" value="time-off"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-off">Time Off</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time to Train" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-to-train" name="tribunal_decision_categories[]" type="checkbox" value="time-to-train"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-to-train">Time to Train</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Membership" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-membership" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-membership"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-membership">Trade Union Membership</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-rights" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-rights">Trade Union Rights</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Transfer of Undertakings" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-transfer-of-undertakings" name="tribunal_decision_categories[]" type="checkbox" value="transfer-of-undertakings"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-transfer-of-undertakings">Transfer of Undertakings</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Unfair Dismissal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-unfair-dismissal" name="tribunal_decision_categories[]" type="checkbox" value="unfair-dismissal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-unfair-dismissal">Unfair Dismissal</label>
# </li> <li class="govuk-checkboxes__item">
# ...
# </ul>
# </section>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </main>
# <div class="gem-c-feedback gem-c-feedback--top-margin" data-module="feedback">
# <div class="gem-c-feedback__prompt gem-c-feedback__js-show js-prompt" tabindex="-1">
# <div class="gem-c-feedback__js-prompt-questions js-prompt-questions">
# <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
# <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#         Maybe
# </a> <ul class="gem-c-feedback__option-list">
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
# <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           Yes <span class="visually-hidden">this page is useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
# <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           No <span class="visually-hidden">this page is not useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
# <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#           Is there anything wrong with this page?
# </a> </li>
# </ul>
# </div>
# <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#     Thank you for your feedback
#   </div>
# </div>
# <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
# <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
# <input name="url" type="hidden" value="https://www.gov.uk/employment-tribunal-decisions?page=1"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-be47dd6e">
#   What were you doing?
# </label>
# <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-be47dd6e" name="what_doing" type="text"/>
# </div>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-c2e1c31d">
#   What went wrong?
# </label>
# <input class="gem-c-input govuk-input" id="input-c2e1c31d" name="what_wrong" type="text"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send</button>
# </div>
# </div>
# </form>
# <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
# <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
# <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
# <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
# <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions?page=1"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-405ba38f">
#   Email address
# </label>
# <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-405ba38f" name="email_survey_signup[email_address]" type="email"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <footer class="group js-footer" id="footer" role="contentinfo">
# <div class="govuk-width-container">
# <div class="footer-container govuk-main-wrapper">
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Transition period</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                Find out what it means for you
#             </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Services and information</h2>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                   Benefits
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                   Births, deaths, marriages and care
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                   Business and self-employed
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                   Childcare and parenting
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                   Citizenship and living in the UK
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                   Crime, justice and the law
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                   Disabled people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                   Driving and transport
#                 </a>
# </li>
# </ul>
# </div>
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                   Education and learning
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                   Employing people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                   Environment and countryside
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                   Housing and local services
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                   Money and tax
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                   Passports, travel and living abroad
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                   Visas and immigration
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                   Working, jobs and pensions
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# <h2>Departments and policy</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#               How government works
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#               Departments
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#               Worldwide
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#               Services
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#               Guidance and regulation
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#               News and communications
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#               Research and statistics
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#               Policy papers and consultations
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#               Transparency and freedom of information releases
#             </a>
# </li>
# </ul>
# </div>
# <hr/>
# </div>
# <div class="footer-meta">
# <div class="footer-meta-inner">
# <h2 class="visuallyhidden">Support links</h2>
# <ul>
# <li><a class="govuk-link" href="/help">Help</a></li>
# <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
# <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
# <li><a class="govuk-link" href="/contact">Contact</a></li>
# <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
# <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
# <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
# <li>
#     Built by the
#     <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#       Government Digital Service
#     </a>
# </li>
# </ul>
# <div class="open-government-licence">
# <p class="logo">
# <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                     Open Government Licence
#                   </a>
# </p>
# <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
# </div>
# </div>
# <div class="copyright">
# <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                  © Crown copyright
#               </a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="app-error hidden" id="global-app-error"></div>
# <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
# <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
# <script src="https://assets.publishing.service.gov.uk/finder-frontend/application-24e2befd8fdd002b4bf83ea458d3d95a87ab18f97cfc6f002560bddcfad8e68a.js"></script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"SearchResultsPage","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions"},"headline":"Employment tribunal decisions","datePublished":"2017-02-08T16:15:17.000+00:00","dateModified":"2020-01-21T14:54:42.000+00:00","description":"Find decisions on Employment Tribunal cases in England, Wales and Scotland.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"]}
# </script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}}]}
# </script>
# </body>
# </html>

# %%
# creates a list with the html for all the pages on the government website within range. 
html = []
for i in range (1,2):
    html.append(get_html_data("https://www.gov.uk/employment-tribunal-decisions?page=" + str(i)))

# %%
html
# Out:
# [<!DOCTYPE html>
#
#  <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]--><!--[if gt IE 8]><!--><html lang="en">
#  <!--<![endif]-->
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." property="og:description"/>
#  <meta content="Employment tribunal decisions" property="og:title"/>
#  <meta content="https://www.gov.uk/employment-tribunal-decisions" property="og:url"/>
#  <meta content="article" property="og:type"/>
#  <meta content="GOV.UK" property="og:site_name"/>
#  <meta content="Employment tribunal decisions - GOV.UK" name="govuk:base_title"/>
#  <meta content="noindex" name="robots"/>
#  <meta content="54673" name="govuk:search-result-count"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
#  <meta content="true" name="govuk:static-analytics:strip-postcodes"/>
#  <meta content="1b5e08c8-ddde-4637-9375-f79e085ba6d5" name="govuk:content-id"/>
#  <meta content="finder" name="govuk:schema-name"/>
#  <meta content="specialist-publisher" name="govuk:publishing-application"/>
#  <meta content="finder" name="govuk:format"/>
#  <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." name="description"/>
#  <meta content="+SMQCD+4fMPn3ZZCI0bizNj7prYLk+p+2jwjaV0ImAr08AgQr08IaayD7oAgGaTa9u09HwFv8iD9gsyr//yU/A==" name="csrf-token"/>
#  <meta content="authenticity_token" name="csrf-param"/>
#  <meta charset="utf-8"/>
#  <title>Employment tribunal decisions - GOV.UK</title>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
#  <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
#  <meta content="#0b0c0c" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/header-footer-only-ef73612898212d607476ed8b99e91f8114bea610dd6a3347ac10b304b33d7206.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/header-footer-only-ie8-02c83f41ee7cfdfa330b28e4216ed7133e679041435c86df85ed233912718532.css" /><script>var ieVersion = 8;</script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/header-footer-only-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
#  <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js"></script>
#  <script>
#        if (GOVUK.globalBarInit) {
#          window.GOVUK.globalBarInit.init()
#        }
#      </script>
#  <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
#  <link href="https://assets.publishing.service.gov.uk/finder-frontend/application-d8e0b3457bbdd3e6ccfe0d74b8978d2664c170509b0e1c7da8eec80be0ce56ec.css" media="screen" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/finder-frontend/print-be4f4422c0e3929d5e90911ea1d3ada170af9fd32dc52c040620a290c7f798b6.css" media="print" rel="stylesheet"/>
#  <link href="/employment-tribunal-decisions.atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
#  <link href="/api/content/employment-tribunal-decisions" rel="alternate" type="application/json"/>
#  <link href="https://www.gov.uk/employment-tribunal-decisions" rel="canonical"/>
#  <meta content="finder-frontend" name="govuk:rendering-application"/>
#  </head>
#  <body class="">
#  <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
#  <div id="skiplink-container">
#  <div>
#  <a class="skiplink govuk-link" href="#content">Skip to main content</a>
#  </div>
#  </div>
#  <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
#  <div class="gem-c-cookie-banner__wrapper govuk-width-container">
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-cookie-banner__message">
#  <span class="govuk-heading-m">Tell us whether you accept cookies</span>
#  <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
#  </div>
#  <div class="gem-c-cookie-banner__buttons">
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
#  </div>
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
#  <p class="gem-c-cookie-banner__confirmation-message">
#        You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#      </p>
#  <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
#  </div>
#  </div>
#  <header class="" id="global-header" role="banner">
#  <div class="header-wrapper">
#  <div class="header-global">
#  <div class="header-logo">
#  <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
#  <span class="govuk-header__logotype">
#  <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
#  <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#  </path>
#  <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
#  </svg>
#  <span class="govuk-header__logotype-text">
#                    GOV.UK
#                  </span>
#  </span>
#  </a>
#  </div>
#  <a class="search-toggle js-header-toggle" href="#search">Search</a>
#  <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
#  <div class="content govuk-clearfix">
#  <label for="site-search-text">Search</label>
#  <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
#  <input class="submit" type="submit" value="Search"/>
#  </div>
#  </form>
#  </div>
#  </div>
#  </header>
#  <div id="user-satisfaction-survey-container"></div>
#  <div id="global-header-bar"></div>
#  <!--[if gt IE 7]><!-->
#  <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
#  <div class="global-bar-message-container">
#  <p class="global-bar-message">
#  <span class="global-bar-title">The UK has left the EU</span>
#  <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
#  </p>
#  <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
#  </div>
#  </div>
#  <!--<![endif]-->
#  <div id="wrapper">
#  <main class="finder-frontend-content" id="content">
#  <div class="finder-frontend">
#  <form action="/employment-tribunal-decisions" class="js-live-search-form" method="get">
#  <input name="parent" type="hidden" value=""/>
#  <div class="govuk-width-container">
#  <div class="gem-c-phase-banner govuk-phase-banner">
#  <p class="govuk-phase-banner__content">
#  <strong class="govuk-tag govuk-phase-banner__content__tag">beta</strong>
#  <span class="govuk-phase-banner__text">This part of GOV.UK is being rebuilt – <a class="govuk-link" href="/help/beta">find out what beta means</a></span>
#  </p>
#  </div>
#  <div class="gem-c-contextual-breadcrumbs">
#  <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
#  <ol class="govuk-breadcrumbs__list">
#  <li aria-current="false" class="govuk-breadcrumbs__list-item">
#  <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
#  </li>
#  </ol>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
#  <h1 class="gem-c-title__text">
#      Employment tribunal decisions
#    </h1>
#  </div>
#  <div class="gem-c-metadata" data-module="gem-toggle">
#  <dl data-module="track-click">
#  <dt class="gem-c-metadata__term">From:</dt>
#  <dd class="gem-c-metadata__definition">
#  <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="govuk-grid-column-two-thirds">
#  <div class="metadata-summary">
#  <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
#  <p>Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.</p>
#  <p>If the decision was made before February 2017, contact <a href="https://courttribunalfinder.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a> for cases in England or Wales, or <a href="https://courttribunalfinder.service.gov.uk/courts/glasgow-tribunal-hearing-centre-eagle-building">Glasgow Tribunal Hearing Centre</a> for cases in Scotland.</p>
#  <p>Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-width-container">
#  <div class="govuk-grid-row">
#  <div aria-label="Employment tribunal decisions" class="govuk-grid-column-one-third" role="search">
#  <div class="filter-form">
#  <div id="keywords">
#  <div class="gem-c-search gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
#  <label class="gem-c-search__label" for="finder-keyword-search">
#              Search <span class="govuk-visually-hidden">Employment tribunal decisions</span>
#  </label>
#  <div class="gem-c-search__item-wrapper">
#  <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
#  <div class="gem-c-search__item gem-c-search__submit-wrapper">
#  <button class="gem-c-search__submit" type="submit">Search</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <button class="app-c-button-as-link app-mobile-filters-link js-show-mobile-filters" data-module="track-click" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#          Filter <span class="govuk-visually-hidden"> results</span>
#  <span class="js-selected-filter-count"></span>
#  </button>
#  <div data-module="track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
#  <a class="gem-c-skip-link govuk-skip-link" href="#js-results">Skip to results</a>
#  </div>
#  <div class="facets" data-module="mobile-filters-modal" id="facet-wrapper">
#  <div class="facets__box">
#  <div class="facets__header">
#  <h1 class="gem-c-title__text">Filter</h1>
#  <button class="app-c-button-as-link facets__return-link js-close-filters" type="button">
#              Return to results
#            </button>
#  </div>
#  <div class="facets__content">
#  <div class="app-c-option-select" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-country">Country</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-0abe2025">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Country</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">England and Wales</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">Scotland</label>
#  </li>
#  </ul>
#  </fieldset>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="app-c-option-select" data-closed-on-load="true" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">Jurisdiction code</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-jurisdiction-code" class="app-c-option-select__container js-options-container" id="tribunal_decision_categories" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-36b163d4">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Jurisdiction code</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Age Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-age-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="age-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-age-discrimination">Age Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Agency Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-agency-workers" name="tribunal_decision_categories[]" type="checkbox" value="agency-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-agency-workers">Agency Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Blacklisting Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-blacklisting-regulations" name="tribunal_decision_categories[]" type="checkbox" value="blacklisting-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-blacklisting-regulations">Blacklisting Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Breach of Contract" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-breach-of-contract" name="tribunal_decision_categories[]" type="checkbox" value="breach-of-contract"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-breach-of-contract">Breach of Contract</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Central Arbitration Committee (CAC)" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-central-arbitration-committee-cac" name="tribunal_decision_categories[]" type="checkbox" value="central-arbitration-committee-cac"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-central-arbitration-committee-cac">Central Arbitration Committee (CAC)</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Certification Officer" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-certification-officer" name="tribunal_decision_categories[]" type="checkbox" value="certification-officer"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-certification-officer">Certification Officer</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Contract of Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-contract-of-employment" name="tribunal_decision_categories[]" type="checkbox" value="contract-of-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-contract-of-employment">Contract of Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Disability Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-disability-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="disability-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-disability-discrimination">Disability Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Employment Agencies Act 1973" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-employment-agencies-act-1973" name="tribunal_decision_categories[]" type="checkbox" value="employment-agencies-act-1973"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-employment-agencies-act-1973">Employment Agencies Act 1973</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Equal Pay Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-equal-pay-act" name="tribunal_decision_categories[]" type="checkbox" value="equal-pay-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-equal-pay-act">Equal Pay Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="European Material" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-european-material" name="tribunal_decision_categories[]" type="checkbox" value="european-material"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-european-material">European Material</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Fixed Term Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-fixed-term-regulations" name="tribunal_decision_categories[]" type="checkbox" value="fixed-term-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-fixed-term-regulations">Fixed Term Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Flexible Working" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-flexible-working" name="tribunal_decision_categories[]" type="checkbox" value="flexible-working"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-flexible-working">Flexible Working</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Harassment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-harassment" name="tribunal_decision_categories[]" type="checkbox" value="harassment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-harassment">Harassment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Health &amp; Safety" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-health-safety" name="tribunal_decision_categories[]" type="checkbox" value="health-safety"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-health-safety">Health &amp; Safety</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Human Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-human-rights" name="tribunal_decision_categories[]" type="checkbox" value="human-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-human-rights">Human Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Improvement Notice" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-improvement-notice" name="tribunal_decision_categories[]" type="checkbox" value="improvement-notice"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-improvement-notice">Improvement Notice</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Interim Relief" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-interim-relief" name="tribunal_decision_categories[]" type="checkbox" value="interim-relief"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-interim-relief">Interim Relief</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Jurisdictional Points" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-jurisdictional-points" name="tribunal_decision_categories[]" type="checkbox" value="jurisdictional-points"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-jurisdictional-points">Jurisdictional Points</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Maternity and Pregnancy Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-maternity-and-pregnancy-rights" name="tribunal_decision_categories[]" type="checkbox" value="maternity-and-pregnancy-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-maternity-and-pregnancy-rights">Maternity and Pregnancy Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Minimum Wage" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-minimum-wage" name="tribunal_decision_categories[]" type="checkbox" value="national-minimum-wage"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-minimum-wage">National Minimum Wage</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Security" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-security" name="tribunal_decision_categories[]" type="checkbox" value="national-security"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-security">National Security</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Notice Appeal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-notice-appeal" name="tribunal_decision_categories[]" type="checkbox" value="notice-appeal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-notice-appeal">Notice Appeal</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Parental and Maternity Leave" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-parental-and-maternity-leave" name="tribunal_decision_categories[]" type="checkbox" value="parental-and-maternity-leave"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-parental-and-maternity-leave">Parental and Maternity Leave</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Part Time Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-part-time-workers" name="tribunal_decision_categories[]" type="checkbox" value="part-time-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-part-time-workers">Part Time Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Pension" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-pension" name="tribunal_decision_categories[]" type="checkbox" value="pension"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-pension">Pension</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Practice and Procedure Issues" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-practice-and-procedure-issues" name="tribunal_decision_categories[]" type="checkbox" value="practice-and-procedure-issues"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-practice-and-procedure-issues">Practice and Procedure Issues</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Protective Award" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-protective-award" name="tribunal_decision_categories[]" type="checkbox" value="protective-award"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-protective-award">Protective Award</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Public Interest Disclosure" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-public-interest-disclosure" name="tribunal_decision_categories[]" type="checkbox" value="public-interest-disclosure"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-public-interest-disclosure">Public Interest Disclosure</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Race Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-race-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="race-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-race-discrimination">Race Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Redundancy" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-redundancy" name="tribunal_decision_categories[]" type="checkbox" value="redundancy"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-redundancy">Redundancy</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Religion or Belief Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-religion-or-belief-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="religion-or-belief-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-religion-or-belief-discrimination">Religion or Belief Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Renumeration" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-renumeration" name="tribunal_decision_categories[]" type="checkbox" value="renumeration"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-renumeration">Renumeration</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reorganisation" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reorganisation" name="tribunal_decision_categories[]" type="checkbox" value="reorganisation"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reorganisation">Reorganisation</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reserved Forces Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reserved-forces-act" name="tribunal_decision_categories[]" type="checkbox" value="reserved-forces-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reserved-forces-act">Reserved Forces Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Right To Be Accompanied" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-right-to-be-accompanied" name="tribunal_decision_categories[]" type="checkbox" value="right-to-be-accompanied"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-right-to-be-accompanied">Right To Be Accompanied</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Rights on Insolvency" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-rights-on-insolvency" name="tribunal_decision_categories[]" type="checkbox" value="rights-on-insolvency"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-rights-on-insolvency">Rights on Insolvency</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sex Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sex-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="sex-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sex-discrimination">Sex Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sexual Orientation Discrimination/Transexualism" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sexual-orientation-discrimination-transexualism" name="tribunal_decision_categories[]" type="checkbox" value="sexual-orientation-discrimination-transexualism"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sexual-orientation-discrimination-transexualism">Sexual Orientation Discrimination/Transexualism</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Statutory Discipline and Grievance Procedures" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-statutory-discipline-and-grievance-procedures" name="tribunal_decision_categories[]" type="checkbox" value="statutory-discipline-and-grievance-procedures"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-statutory-discipline-and-grievance-procedures">Statutory Discipline and Grievance Procedures</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Tax" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-tax" name="tribunal_decision_categories[]" type="checkbox" value="tax"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-tax">Tax</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Temporary Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-temporary-employment" name="tribunal_decision_categories[]" type="checkbox" value="temporary-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-temporary-employment">Temporary Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Limits" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-limits" name="tribunal_decision_categories[]" type="checkbox" value="time-limits"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-limits">Time Limits</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Off" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-off" name="tribunal_decision_categories[]" type="checkbox" value="time-off"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-off">Time Off</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time to Train" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-to-train" name="tribunal_decision_categories[]" type="checkbox" value="time-to-train"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-to-train">Time to Train</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Membership" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-membership" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-membership"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-membership">Trade Union Membership</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-rights" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-rights">Trade Union Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Transfer of Undertakings" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-transfer-of-undertakings" name="tribunal_decision_categories[]" type="checkbox" value="transfer-of-undertakings"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-transfer-of-undertakings">Transfer of Undertakings</label>
#  </li> <li class="govuk-checkboxes__item">
# ...
#  <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
#  <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#          Maybe
#  </a> <ul class="gem-c-feedback__option-list">
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
#  <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            Yes <span class="visually-hidden">this page is useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
#  <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            No <span class="visually-hidden">this page is not useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
#  <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#            Is there anything wrong with this page?
#  </a> </li>
#  </ul>
#  </div>
#  <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#      Thank you for your feedback
#    </div>
#  </div>
#  <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
#  <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
#  <input name="url" type="hidden" value="https://www.gov.uk/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-be47dd6e">
#    What were you doing?
#  </label>
#  <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-be47dd6e" name="what_doing" type="text"/>
#  </div>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-c2e1c31d">
#    What went wrong?
#  </label>
#  <input class="gem-c-input govuk-input" id="input-c2e1c31d" name="what_wrong" type="text"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send</button>
#  </div>
#  </div>
#  </form>
#  <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
#  <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
#  <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
#  <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
#  <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-405ba38f">
#    Email address
#  </label>
#  <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-405ba38f" name="email_survey_signup[email_address]" type="email"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  <footer class="group js-footer" id="footer" role="contentinfo">
#  <div class="govuk-width-container">
#  <div class="footer-container govuk-main-wrapper">
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Transition period</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                 Find out what it means for you
#              </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Services and information</h2>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                    Benefits
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                    Births, deaths, marriages and care
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                    Business and self-employed
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                    Childcare and parenting
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                    Citizenship and living in the UK
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                    Crime, justice and the law
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                    Disabled people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                    Driving and transport
#                  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                    Education and learning
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                    Employing people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                    Environment and countryside
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                    Housing and local services
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                    Money and tax
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                    Passports, travel and living abroad
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                    Visas and immigration
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                    Working, jobs and pensions
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  <h2>Departments and policy</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#                How government works
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#                Departments
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#                Worldwide
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#                Services
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#                Guidance and regulation
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#                News and communications
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#                Research and statistics
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#                Policy papers and consultations
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#                Transparency and freedom of information releases
#              </a>
#  </li>
#  </ul>
#  </div>
#  <hr/>
#  </div>
#  <div class="footer-meta">
#  <div class="footer-meta-inner">
#  <h2 class="visuallyhidden">Support links</h2>
#  <ul>
#  <li><a class="govuk-link" href="/help">Help</a></li>
#  <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
#  <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
#  <li><a class="govuk-link" href="/contact">Contact</a></li>
#  <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
#  <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
#  <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
#  <li>
#      Built by the
#      <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#        Government Digital Service
#      </a>
#  </li>
#  </ul>
#  <div class="open-government-licence">
#  <p class="logo">
#  <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                      Open Government Licence
#                    </a>
#  </p>
#  <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
#  </div>
#  </div>
#  <div class="copyright">
#  <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                   © Crown copyright
#                </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </footer>
#  <div class="app-error hidden" id="global-app-error"></div>
#  <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
#  <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
#  <script src="https://assets.publishing.service.gov.uk/finder-frontend/application-24e2befd8fdd002b4bf83ea458d3d95a87ab18f97cfc6f002560bddcfad8e68a.js"></script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"SearchResultsPage","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions"},"headline":"Employment tribunal decisions","datePublished":"2017-02-08T16:15:17.000+00:00","dateModified":"2020-01-21T14:54:42.000+00:00","description":"Find decisions on Employment Tribunal cases in England, Wales and Scotland.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"]}
#  </script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}}]}
#  </script>
#  </body>
#  </html>]

# %%
page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page=1")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." property="og:description"/>
#   <meta content="Employment tribunal decisions" property="og:title"/>
#   <meta content="https://www.gov.uk/employment-tribunal-decisions" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="GOV.UK" property="og:site_name"/>
#   <meta content="Employment tribunal decisions - GOV.UK" name="govuk:base_title"/>
#   <meta content="noindex" name="robots"/>
#   <meta content="54673" name="govuk:search-result-count"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
#   <meta content="true" name="govuk:static-analytics:strip-postcodes"/>
#   <meta content="1b5e08c8-ddde-4637-9375-f79e085ba6d5" name="govuk:content-id"/>
#   <meta content="finder" name="govuk:schema-name"/>
#   <meta content="specialist-publisher" name="govuk:publishing-application"/>
#   <meta content="finder" name="govuk:format"/>
#   <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." name="description"/>
#   <meta content="NRcUgnkn+8XfGHqvEIrM9AQ5649wc40wAFh7nSow2Gp0b4cj6M5O4SzYUcIM1G9FqwILWeqkzf9dzGB1GYiI6w==" name="csrf-token"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta charset="utf-8"/>
#   <title>
#    Employment tribunal decisions - GOV.UK
#   </title>
#   <!--[if gt IE 8]><!-->
#   <link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
#   <!--<![endif]-->
#   <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
#   <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
#   <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
#   <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
#   <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
#   <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
#   <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
#   <meta content="#0b0c0c" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!--[if gt IE 8]><!-->
#   <link href="https://assets.publishing.service.gov.uk/static/header-footer-only-ef73612898212d607476ed8b99e91f8114bea610dd6a3347ac10b304b33d7206.css" media="screen" rel="stylesheet"/>
#   <!--<![endif]-->
#   <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/header-footer-only-ie8-02c83f41ee7cfdfa330b28e4216ed7133e679041435c86df85ed233912718532.css" /><script>var ieVersion = 8;</script><![endif]-->
#   <link href="https://assets.publishing.service.gov.uk/static/header-footer-only-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
#   <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js">
#   </script>
#   <script>
#    if (GOVUK.globalBarInit) {
#         window.GOVUK.globalBarInit.init()
#       }
#   </script>
#   <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
#   <link href="https://assets.publishing.service.gov.uk/finder-frontend/application-d8e0b3457bbdd3e6ccfe0d74b8978d2664c170509b0e1c7da8eec80be0ce56ec.css" media="screen" rel="stylesheet"/>
#   <link href="https://assets.publishing.service.gov.uk/finder-frontend/print-be4f4422c0e3929d5e90911ea1d3ada170af9fd32dc52c040620a290c7f798b6.css" media="print" rel="stylesheet"/>
#   <link href="/employment-tribunal-decisions.atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
#   <link href="/api/content/employment-tribunal-decisions" rel="alternate" type="application/json"/>
#   <link href="https://www.gov.uk/employment-tribunal-decisions" rel="canonical"/>
#   <meta content="finder-frontend" name="govuk:rendering-application"/>
#  </head>
#  <body class="">
#   <script>
#    document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');
#   </script>
#   <div id="skiplink-container">
#    <div>
#     <a class="skiplink govuk-link" href="#content">
#      Skip to main content
#     </a>
#    </div>
#   </div>
#   <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
#    <div class="gem-c-cookie-banner__wrapper govuk-width-container">
#     <div class="govuk-grid-row">
#      <div class="govuk-grid-column-two-thirds">
#       <div class="gem-c-cookie-banner__message">
#        <span class="govuk-heading-m">
#         Tell us whether you accept cookies
#        </span>
#        <p class="govuk-body">
#         We use
#         <a class="govuk-link" href="/help/cookies">
#          cookies to collect information
#         </a>
#         about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.
#        </p>
#       </div>
#       <div class="gem-c-cookie-banner__buttons">
#        <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#         <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">
#          Accept all cookies
#         </button>
#        </div>
#        <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#         <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">
#          Set cookie preferences
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
#     <p class="gem-c-cookie-banner__confirmation-message">
#      You’ve accepted all cookies. You can
#      <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">
#       change your cookie settings
#      </a>
#      at any time.
#     </p>
#     <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">
#      Hide
#     </button>
#    </div>
#   </div>
#   <header class="" id="global-header" role="banner">
#    <div class="header-wrapper">
#     <div class="header-global">
#      <div class="header-logo">
#       <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
#        <span class="govuk-header__logotype">
#         <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
#          <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#          </path>
#          <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
#         </svg>
#         <span class="govuk-header__logotype-text">
#          GOV.UK
#         </span>
#        </span>
#       </a>
#      </div>
#      <a class="search-toggle js-header-toggle" href="#search">
#       Search
#      </a>
#      <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
#       <div class="content govuk-clearfix">
#        <label for="site-search-text">
#         Search
#        </label>
#        <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
#        <input class="submit" type="submit" value="Search"/>
#       </div>
#      </form>
#     </div>
#    </div>
#   </header>
#   <div id="user-satisfaction-survey-container">
#   </div>
#   <div id="global-header-bar">
#   </div>
#   <!--[if gt IE 7]><!-->
#   <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
#    <div class="global-bar-message-container">
#     <p class="global-bar-message">
#      <span class="global-bar-title">
#       The UK has left the EU
#      </span>
#      <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">
#       Find out what this means for you
#      </a>
#     </p>
#     <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">
#      Hide message
#     </a>
#    </div>
#   </div>
#   <!--<![endif]-->
#   <div id="wrapper">
#    <main class="finder-frontend-content" id="content">
#     <div class="finder-frontend">
#      <form action="/employment-tribunal-decisions" class="js-live-search-form" method="get">
#       <input name="parent" type="hidden" value=""/>
#       <div class="govuk-width-container">
#        <div class="gem-c-phase-banner govuk-phase-banner">
#         <p class="govuk-phase-banner__content">
#          <strong class="govuk-tag govuk-phase-banner__content__tag">
#           beta
#          </strong>
#          <span class="govuk-phase-banner__text">
#           This part of GOV.UK is being rebuilt –
#           <a class="govuk-link" href="/help/beta">
#            find out what beta means
#           </a>
#          </span>
#         </p>
#        </div>
#        <div class="gem-c-contextual-breadcrumbs">
#         <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
#          <ol class="govuk-breadcrumbs__list">
#           <li aria-current="false" class="govuk-breadcrumbs__list-item">
#            <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">
#             Home
#            </a>
#           </li>
#          </ol>
#         </div>
#        </div>
#        <div class="govuk-grid-row">
#         <div class="govuk-grid-column-two-thirds">
#          <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
#           <h1 class="gem-c-title__text">
#            Employment tribunal decisions
#           </h1>
#          </div>
#          <div class="gem-c-metadata" data-module="gem-toggle">
#           <dl data-module="track-click">
#            <dt class="gem-c-metadata__term">
#             From:
#            </dt>
#            <dd class="gem-c-metadata__definition">
#             <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">
#              HM Courts &amp; Tribunals Service
#             </a>
#             and
#             <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">
#              Employment Tribunal
#             </a>
#            </dd>
#           </dl>
#          </div>
#         </div>
#         <div class="govuk-grid-column-two-thirds">
#          <div class="metadata-summary">
#           <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
#            <p>
#             Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.
#            </p>
#            <p>
#             If the decision was made before February 2017, contact
#             <a href="https://courttribunalfinder.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">
#              Bury St Edmunds County Court
#             </a>
#             for cases in England or Wales, or
#             <a href="https://courttribunalfinder.service.gov.uk/courts/glasgow-tribunal-hearing-centre-eagle-building">
#              Glasgow Tribunal Hearing Centre
#             </a>
#             for cases in Scotland.
#            </p>
#            <p>
#             Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.
#            </p>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="govuk-width-container">
#        <div class="govuk-grid-row">
#         <div aria-label="Employment tribunal decisions" class="govuk-grid-column-one-third" role="search">
#          <div class="filter-form">
#           <div id="keywords">
#            <div class="gem-c-search gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
#             <label class="gem-c-search__label" for="finder-keyword-search">
#              Search
#              <span class="govuk-visually-hidden">
#               Employment tribunal decisions
#              </span>
#             </label>
#             <div class="gem-c-search__item-wrapper">
#              <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
#              <div class="gem-c-search__item gem-c-search__submit-wrapper">
#               <button class="gem-c-search__submit" type="submit">
#                Search
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#           <button class="app-c-button-as-link app-mobile-filters-link js-show-mobile-filters" data-module="track-click" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#            Filter
#            <span class="govuk-visually-hidden">
#             results
#            </span>
#            <span class="js-selected-filter-count">
#            </span>
#           </button>
#           <div data-module="track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
#            <a class="gem-c-skip-link govuk-skip-link" href="#js-results">
#             Skip to results
#            </a>
#           </div>
#           <div class="facets" data-module="mobile-filters-modal" id="facet-wrapper">
#            <div class="facets__box">
#             <div class="facets__header">
#              <h1 class="gem-c-title__text">
#               Filter
#              </h1>
#              <button class="app-c-button-as-link facets__return-link js-close-filters" type="button">
#               Return to results
#              </button>
#             </div>
#             <div class="facets__content">
#              <div class="app-c-option-select" data-input-aria-controls="js-search-results-info" data-module="option-select">
#               <h2 class="app-c-option-select__heading js-container-heading">
#                <span class="app-c-option-select__title js-container-button" id="option-select-title-country">
#                 Country
#                </span>
#                <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg">
#                 <path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z">
#                 </path>
#                </svg>
#                <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg">
#                 <path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z">
#                 </path>
#                </svg>
#               </h2>
#               <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
#                <div class="app-c-option-select__container-inner js-auto-height-inner">
#                 <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-1aa5b9a8">
#                  <fieldset class="govuk-fieldset">
#                   <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">
#                    Country
#                   </legend>
#                   <ul class="govuk-checkboxes gem-c-checkboxes__list">
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">
#                      England and Wales
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">
#                      Scotland
#                     </label>
#                    </li>
#                   </ul>
#                  </fieldset>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="app-c-option-select" data-closed-on-load="true" data-input-aria-controls="js-search-results-info" data-module="option-select">
#               <h2 class="app-c-option-select__heading js-container-heading">
#                <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">
#                 Jurisdiction code
#                </span>
#                <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg">
#                 <path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z">
#                 </path>
#                </svg>
#                <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg">
#                 <path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z">
#                 </path>
#                </svg>
#               </h2>
#               <div aria-labelledby="option-select-title-jurisdiction-code" class="app-c-option-select__container js-options-container" id="tribunal_decision_categories" role="group" tabindex="-1">
#                <div class="app-c-option-select__container-inner js-auto-height-inner">
#                 <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-759922cf">
#                  <fieldset class="govuk-fieldset">
#                   <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">
#                    Jurisdiction code
#                   </legend>
#                   <ul class="govuk-checkboxes gem-c-checkboxes__list">
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Age Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-age-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="age-discrimination"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-age-discrimination">
#                      Age Discrimination
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Agency Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-agency-workers" name="tribunal_decision_categories[]" type="checkbox" value="agency-workers"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-agency-workers">
#                      Agency Workers
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Blacklisting Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-blacklisting-regulations" name="tribunal_decision_categories[]" type="checkbox" value="blacklisting-regulations"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-blacklisting-regulations">
#                      Blacklisting Regulations
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Breach of Contract" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-breach-of-contract" name="tribunal_decision_categories[]" type="checkbox" value="breach-of-contract"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-breach-of-contract">
#                      Breach of Contract
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Central Arbitration Committee (CAC)" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-central-arbitration-committee-cac" name="tribunal_decision_categories[]" type="checkbox" value="central-arbitration-committee-cac"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-central-arbitration-committee-cac">
#                      Central Arbitration Committee (CAC)
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Certification Officer" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-certification-officer" name="tribunal_decision_categories[]" type="checkbox" value="certification-officer"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-certification-officer">
#                      Certification Officer
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Contract of Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-contract-of-employment" name="tribunal_decision_categories[]" type="checkbox" value="contract-of-employment"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-contract-of-employment">
#                      Contract of Employment
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Disability Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-disability-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="disability-discrimination"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-disability-discrimination">
#                      Disability Discrimination
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Employment Agencies Act 1973" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-employment-agencies-act-1973" name="tribunal_decision_categories[]" type="checkbox" value="employment-agencies-act-1973"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-employment-agencies-act-1973">
#                      Employment Agencies Act 1973
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Equal Pay Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-equal-pay-act" name="tribunal_decision_categories[]" type="checkbox" value="equal-pay-act"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-equal-pay-act">
#                      Equal Pay Act
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="European Material" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-european-material" name="tribunal_decision_categories[]" type="checkbox" value="european-material"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-european-material">
#                      European Material
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Fixed Term Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-fixed-term-regulations" name="tribunal_decision_categories[]" type="checkbox" value="fixed-term-regulations"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-fixed-term-regulations">
#                      Fixed Term Regulations
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Flexible Working" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-flexible-working" name="tribunal_decision_categories[]" type="checkbox" value="flexible-working"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-flexible-working">
#                      Flexible Working
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Harassment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-harassment" name="tribunal_decision_categories[]" type="checkbox" value="harassment"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-harassment">
#                      Harassment
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Health &amp; Safety" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-health-safety" name="tribunal_decision_categories[]" type="checkbox" value="health-safety"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-health-safety">
#                      Health &amp; Safety
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Human Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-human-rights" name="tribunal_decision_categories[]" type="checkbox" value="human-rights"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-human-rights">
#                      Human Rights
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Improvement Notice" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-improvement-notice" name="tribunal_decision_categories[]" type="checkbox" value="improvement-notice"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-improvement-notice">
#                      Improvement Notice
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Interim Relief" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-interim-relief" name="tribunal_decision_categories[]" type="checkbox" value="interim-relief"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-interim-relief">
#                      Interim Relief
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Jurisdictional Points" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-jurisdictional-points" name="tribunal_decision_categories[]" type="checkbox" value="jurisdictional-points"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-jurisdictional-points">
#                      Jurisdictional Points
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Maternity and Pregnancy Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-maternity-and-pregnancy-rights" name="tribunal_decision_categories[]" type="checkbox" value="maternity-and-pregnancy-rights"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-maternity-and-pregnancy-rights">
#                      Maternity and Pregnancy Rights
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Minimum Wage" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-minimum-wage" name="tribunal_decision_categories[]" type="checkbox" value="national-minimum-wage"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-minimum-wage">
#                      National Minimum Wage
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Security" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-security" name="tribunal_decision_categories[]" type="checkbox" value="national-security"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-security">
#                      National Security
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Notice Appeal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-notice-appeal" name="tribunal_decision_categories[]" type="checkbox" value="notice-appeal"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-notice-appeal">
#                      Notice Appeal
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Parental and Maternity Leave" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-parental-and-maternity-leave" name="tribunal_decision_categories[]" type="checkbox" value="parental-and-maternity-leave"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-parental-and-maternity-leave">
#                      Parental and Maternity Leave
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Part Time Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-part-time-workers" name="tribunal_decision_categories[]" type="checkbox" value="part-time-workers"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-part-time-workers">
#                      Part Time Workers
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Pension" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-pension" name="tribunal_decision_categories[]" type="checkbox" value="pension"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-pension">
#                      Pension
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Practice and Procedure Issues" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-practice-and-procedure-issues" name="tribunal_decision_categories[]" type="checkbox" value="practice-and-procedure-issues"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-practice-and-procedure-issues">
#                      Practice and Procedure Issues
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Protective Award" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-protective-award" name="tribunal_decision_categories[]" type="checkbox" value="protective-award"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-protective-award">
#                      Protective Award
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Public Interest Disclosure" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-public-interest-disclosure" name="tribunal_decision_categories[]" type="checkbox" value="public-interest-disclosure"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-public-interest-disclosure">
#                      Public Interest Disclosure
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Race Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-race-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="race-discrimination"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-race-discrimination">
#                      Race Discrimination
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Redundancy" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-redundancy" name="tribunal_decision_categories[]" type="checkbox" value="redundancy"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-redundancy">
#                      Redundancy
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Religion or Belief Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-religion-or-belief-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="religion-or-belief-discrimination"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-religion-or-belief-discrimination">
#                      Religion or Belief Discrimination
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Renumeration" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-renumeration" name="tribunal_decision_categories[]" type="checkbox" value="renumeration"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-renumeration">
#                      Renumeration
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reorganisation" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reorganisation" name="tribunal_decision_categories[]" type="checkbox" value="reorganisation"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reorganisation">
#                      Reorganisation
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reserved Forces Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reserved-forces-act" name="tribunal_decision_categories[]" type="checkbox" value="reserved-forces-act"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reserved-forces-act">
#                      Reserved Forces Act
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
#                     <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Right To Be Accompanied" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-right-to-be-accompanied" name="tribunal_decision_categories[]" type="checkbox" value="right-to-be-accompanied"/>
#                     <label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-right-to-be-accompanied">
#                      Right To Be Accompanied
#                     </label>
#                    </li>
#                    <li class="govuk-checkboxes__item">
# ...
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#       Thank you for your feedback
#      </div>
#     </div>
#     <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
#      <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">
#       Close
#      </a>
#      <div class="govuk-grid-row">
#       <div class="govuk-grid-column-two-thirds">
#        <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1">
#        </div>
#        <input name="url" type="hidden" value="https://www.gov.uk/employment-tribunal-decisions?page=1"/>
#        <h3 class="gem-c-feedback__form-heading">
#         Help us improve GOV.UK
#        </h3>
#        <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">
#         Don’t include personal or financial information like your National Insurance number or credit card details.
#        </p>
#        <div class="govuk-form-group">
#         <label class="gem-c-label govuk-label" for="input-fa4d6848">
#          What were you doing?
#         </label>
#         <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-fa4d6848" name="what_doing" type="text"/>
#        </div>
#        <div class="govuk-form-group">
#         <label class="gem-c-label govuk-label" for="input-5c3f3a0c">
#          What went wrong?
#         </label>
#         <input class="gem-c-input govuk-input" id="input-5c3f3a0c" name="what_wrong" type="text"/>
#        </div>
#        <button class="gem-c-button govuk-button" type="submit">
#         Send
#        </button>
#       </div>
#      </div>
#     </form>
#     <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
#      <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">
#       Close
#      </a>
#      <div class="govuk-grid-row">
#       <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
#        <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1">
#        </div>
#        <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
#        <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions?page=1"/>
#        <h3 class="gem-c-feedback__form-heading">
#         Help us improve GOV.UK
#        </h3>
#        <p class="gem-c-feedback__form-paragraph" id="survey_explanation">
#         To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.
#        </p>
#        <div class="govuk-form-group">
#         <label class="gem-c-label govuk-label" for="input-9f3fe982">
#          Email address
#         </label>
#         <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-9f3fe982" name="email_survey_signup[email_address]" type="email"/>
#        </div>
#        <button class="gem-c-button govuk-button" type="submit">
#         Send me the survey
#        </button>
#       </div>
#      </div>
#     </form>
#    </div>
#   </div>
#   <footer class="group js-footer" id="footer" role="contentinfo">
#    <div class="govuk-width-container">
#     <div class="footer-container govuk-main-wrapper">
#      <div class="govuk-grid-row footer-categories" data-module="track-click">
#       <div class="govuk-grid-column-two-thirds">
#        <h2>
#         Transition period
#        </h2>
#        <ul>
#         <li>
#          <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#           Find out what it means for you
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="govuk-grid-row footer-categories" data-module="track-click">
#       <div class="govuk-grid-column-two-thirds">
#        <h2>
#         Services and information
#        </h2>
#        <div class="govuk-grid-row">
#         <div class="govuk-grid-column-one-half">
#          <ul>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#             Benefits
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#             Births, deaths, marriages and care
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#             Business and self-employed
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#             Childcare and parenting
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#             Citizenship and living in the UK
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#             Crime, justice and the law
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#             Disabled people
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#             Driving and transport
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="govuk-grid-column-one-half">
#          <ul>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#             Education and learning
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#             Employing people
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#             Environment and countryside
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#             Housing and local services
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#             Money and tax
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#             Passports, travel and living abroad
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#             Visas and immigration
#            </a>
#           </li>
#           <li>
#            <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#             Working, jobs and pensions
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="govuk-grid-column-one-third">
#        <h2>
#         Departments and policy
#        </h2>
#        <ul>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#           How government works
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#           Departments
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#           Worldwide
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#           Services
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#           Guidance and regulation
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#           News and communications
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#           Research and statistics
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#           Policy papers and consultations
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#           Transparency and freedom of information releases
#          </a>
#         </li>
#        </ul>
#       </div>
#       <hr/>
#      </div>
#      <div class="footer-meta">
#       <div class="footer-meta-inner">
#        <h2 class="visuallyhidden">
#         Support links
#        </h2>
#        <ul>
#         <li>
#          <a class="govuk-link" href="/help">
#           Help
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/help/privacy-notice">
#           Privacy
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/help/cookies">
#           Cookies
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/contact">
#           Contact
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/help/accessibility-statement">
#           Accessibility statement
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/help/terms-conditions">
#           Terms and conditions
#          </a>
#         </li>
#         <li>
#          <a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">
#           Rhestr o Wasanaethau Cymraeg
#          </a>
#         </li>
#         <li>
#          Built by the
#          <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#           Government Digital Service
#          </a>
#         </li>
#        </ul>
#        <div class="open-government-licence">
#         <p class="logo">
#          <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#           Open Government Licence
#          </a>
#         </p>
#         <p>
#          All content is available under the
#          <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#           Open Government Licence v3.0
#          </a>
#          , except where otherwise stated
#         </p>
#        </div>
#       </div>
#       <div class="copyright">
#        <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#         © Crown copyright
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="app-error hidden" id="global-app-error">
#   </div>
#   <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js">
#   </script>
#   <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js">
#   </script>
#   <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js">
#   </script>
#   <script>
#    if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');
#   </script>
#   <script src="https://assets.publishing.service.gov.uk/finder-frontend/application-24e2befd8fdd002b4bf83ea458d3d95a87ab18f97cfc6f002560bddcfad8e68a.js">
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"SearchResultsPage","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions"},"headline":"Employment tribunal decisions","datePublished":"2017-02-08T16:15:17.000+00:00","dateModified":"2020-01-21T14:54:42.000+00:00","description":"Find decisions on Employment Tribunal cases in England, Wales and Scotland.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"]}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}}]}
#   </script>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  '[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]',
#  '[if gt IE 8]><!',
#  <html lang="en">
#  <!--<![endif]-->
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." property="og:description"/>
#  <meta content="Employment tribunal decisions" property="og:title"/>
#  <meta content="https://www.gov.uk/employment-tribunal-decisions" property="og:url"/>
#  <meta content="article" property="og:type"/>
#  <meta content="GOV.UK" property="og:site_name"/>
#  <meta content="Employment tribunal decisions - GOV.UK" name="govuk:base_title"/>
#  <meta content="noindex" name="robots"/>
#  <meta content="54673" name="govuk:search-result-count"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
#  <meta content="true" name="govuk:static-analytics:strip-postcodes"/>
#  <meta content="1b5e08c8-ddde-4637-9375-f79e085ba6d5" name="govuk:content-id"/>
#  <meta content="finder" name="govuk:schema-name"/>
#  <meta content="specialist-publisher" name="govuk:publishing-application"/>
#  <meta content="finder" name="govuk:format"/>
#  <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." name="description"/>
#  <meta content="NRcUgnkn+8XfGHqvEIrM9AQ5649wc40wAFh7nSow2Gp0b4cj6M5O4SzYUcIM1G9FqwILWeqkzf9dzGB1GYiI6w==" name="csrf-token"/>
#  <meta content="authenticity_token" name="csrf-param"/>
#  <meta charset="utf-8"/>
#  <title>Employment tribunal decisions - GOV.UK</title>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
#  <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
#  <meta content="#0b0c0c" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/header-footer-only-ef73612898212d607476ed8b99e91f8114bea610dd6a3347ac10b304b33d7206.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/header-footer-only-ie8-02c83f41ee7cfdfa330b28e4216ed7133e679041435c86df85ed233912718532.css" /><script>var ieVersion = 8;</script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/header-footer-only-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
#  <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js"></script>
#  <script>
#        if (GOVUK.globalBarInit) {
#          window.GOVUK.globalBarInit.init()
#        }
#      </script>
#  <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
#  <link href="https://assets.publishing.service.gov.uk/finder-frontend/application-d8e0b3457bbdd3e6ccfe0d74b8978d2664c170509b0e1c7da8eec80be0ce56ec.css" media="screen" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/finder-frontend/print-be4f4422c0e3929d5e90911ea1d3ada170af9fd32dc52c040620a290c7f798b6.css" media="print" rel="stylesheet"/>
#  <link href="/employment-tribunal-decisions.atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
#  <link href="/api/content/employment-tribunal-decisions" rel="alternate" type="application/json"/>
#  <link href="https://www.gov.uk/employment-tribunal-decisions" rel="canonical"/>
#  <meta content="finder-frontend" name="govuk:rendering-application"/>
#  </head>
#  <body class="">
#  <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
#  <div id="skiplink-container">
#  <div>
#  <a class="skiplink govuk-link" href="#content">Skip to main content</a>
#  </div>
#  </div>
#  <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
#  <div class="gem-c-cookie-banner__wrapper govuk-width-container">
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-cookie-banner__message">
#  <span class="govuk-heading-m">Tell us whether you accept cookies</span>
#  <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
#  </div>
#  <div class="gem-c-cookie-banner__buttons">
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
#  </div>
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
#  <p class="gem-c-cookie-banner__confirmation-message">
#        You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#      </p>
#  <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
#  </div>
#  </div>
#  <header class="" id="global-header" role="banner">
#  <div class="header-wrapper">
#  <div class="header-global">
#  <div class="header-logo">
#  <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#  </path>
#  <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
#  </svg>
#  <span class="govuk-header__logotype-text">
#                    GOV.UK
#                  </span>
#  </span>
#  </a>
#  </div>
#  <a class="search-toggle js-header-toggle" href="#search">Search</a>
#  <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
#  <div class="content govuk-clearfix">
#  <label for="site-search-text">Search</label>
#  <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
#  <input class="submit" type="submit" value="Search"/>
#  </div>
#  </form>
#  </div>
#  </div>
#  </header>
#  <div id="user-satisfaction-survey-container"></div>
#  <div id="global-header-bar"></div>
#  <!--[if gt IE 7]><!-->
#  <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
#  <div class="global-bar-message-container">
#  <p class="global-bar-message">
#  <span class="global-bar-title">The UK has left the EU</span>
#  <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
#  </p>
#  <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
#  </div>
#  </div>
#  <!--<![endif]-->
#  <div id="wrapper">
#  <main class="finder-frontend-content" id="content">
#  <div class="finder-frontend">
#  <form action="/employment-tribunal-decisions" class="js-live-search-form" method="get">
#  <input name="parent" type="hidden" value=""/>
#  <div class="govuk-width-container">
#  <div class="gem-c-phase-banner govuk-phase-banner">
#  <p class="govuk-phase-banner__content">
#  <strong class="govuk-tag govuk-phase-banner__content__tag">beta</strong>
#  <span class="govuk-phase-banner__text">This part of GOV.UK is being rebuilt – <a class="govuk-link" href="/help/beta">find out what beta means</a></span>
#  </p>
#  </div>
#  <div class="gem-c-contextual-breadcrumbs">
#  <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
#  <ol class="govuk-breadcrumbs__list">
#  <li aria-current="false" class="govuk-breadcrumbs__list-item">
#  <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
#  </li>
#  </ol>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
#  <h1 class="gem-c-title__text">
#      Employment tribunal decisions
#    </h1>
#  </div>
#  <div class="gem-c-metadata" data-module="gem-toggle">
#  <dl data-module="track-click">
#  <dt class="gem-c-metadata__term">From:</dt>
#  <dd class="gem-c-metadata__definition">
#  <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="govuk-grid-column-two-thirds">
#  <div class="metadata-summary">
#  <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
#  <p>Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.</p>
#  <p>If the decision was made before February 2017, contact <a href="https://courttribunalfinder.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a> for cases in England or Wales, or <a href="https://courttribunalfinder.service.gov.uk/courts/glasgow-tribunal-hearing-centre-eagle-building">Glasgow Tribunal Hearing Centre</a> for cases in Scotland.</p>
#  <p>Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-width-container">
#  <div class="govuk-grid-row">
#  <div aria-label="Employment tribunal decisions" class="govuk-grid-column-one-third" role="search">
#  <div class="filter-form">
#  <div id="keywords">
#  <div class="gem-c-search gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
#  <label class="gem-c-search__label" for="finder-keyword-search">
#              Search <span class="govuk-visually-hidden">Employment tribunal decisions</span>
#  </label>
#  <div class="gem-c-search__item-wrapper">
#  <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
#  <div class="gem-c-search__item gem-c-search__submit-wrapper">
#  <button class="gem-c-search__submit" type="submit">Search</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <button class="app-c-button-as-link app-mobile-filters-link js-show-mobile-filters" data-module="track-click" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#          Filter <span class="govuk-visually-hidden"> results</span>
#  <span class="js-selected-filter-count"></span>
#  </button>
#  <div data-module="track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
#  <a class="gem-c-skip-link govuk-skip-link" href="#js-results">Skip to results</a>
#  </div>
#  <div class="facets" data-module="mobile-filters-modal" id="facet-wrapper">
#  <div class="facets__box">
#  <div class="facets__header">
#  <h1 class="gem-c-title__text">Filter</h1>
#  <button class="app-c-button-as-link facets__return-link js-close-filters" type="button">
#              Return to results
#            </button>
#  </div>
#  <div class="facets__content">
#  <div class="app-c-option-select" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-country">Country</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-1aa5b9a8">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Country</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">England and Wales</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">Scotland</label>
#  </li>
#  </ul>
#  </fieldset>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="app-c-option-select" data-closed-on-load="true" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">Jurisdiction code</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-jurisdiction-code" class="app-c-option-select__container js-options-container" id="tribunal_decision_categories" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-759922cf">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Jurisdiction code</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Age Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-age-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="age-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-age-discrimination">Age Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Agency Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-agency-workers" name="tribunal_decision_categories[]" type="checkbox" value="agency-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-agency-workers">Agency Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Blacklisting Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-blacklisting-regulations" name="tribunal_decision_categories[]" type="checkbox" value="blacklisting-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-blacklisting-regulations">Blacklisting Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Breach of Contract" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-breach-of-contract" name="tribunal_decision_categories[]" type="checkbox" value="breach-of-contract"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-breach-of-contract">Breach of Contract</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Central Arbitration Committee (CAC)" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-central-arbitration-committee-cac" name="tribunal_decision_categories[]" type="checkbox" value="central-arbitration-committee-cac"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-central-arbitration-committee-cac">Central Arbitration Committee (CAC)</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Certification Officer" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-certification-officer" name="tribunal_decision_categories[]" type="checkbox" value="certification-officer"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-certification-officer">Certification Officer</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Contract of Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-contract-of-employment" name="tribunal_decision_categories[]" type="checkbox" value="contract-of-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-contract-of-employment">Contract of Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Disability Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-disability-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="disability-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-disability-discrimination">Disability Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Employment Agencies Act 1973" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-employment-agencies-act-1973" name="tribunal_decision_categories[]" type="checkbox" value="employment-agencies-act-1973"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-employment-agencies-act-1973">Employment Agencies Act 1973</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Equal Pay Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-equal-pay-act" name="tribunal_decision_categories[]" type="checkbox" value="equal-pay-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-equal-pay-act">Equal Pay Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="European Material" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-european-material" name="tribunal_decision_categories[]" type="checkbox" value="european-material"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-european-material">European Material</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Fixed Term Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-fixed-term-regulations" name="tribunal_decision_categories[]" type="checkbox" value="fixed-term-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-fixed-term-regulations">Fixed Term Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Flexible Working" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-flexible-working" name="tribunal_decision_categories[]" type="checkbox" value="flexible-working"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-flexible-working">Flexible Working</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Harassment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-harassment" name="tribunal_decision_categories[]" type="checkbox" value="harassment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-harassment">Harassment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Health &amp; Safety" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-health-safety" name="tribunal_decision_categories[]" type="checkbox" value="health-safety"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-health-safety">Health &amp; Safety</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Human Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-human-rights" name="tribunal_decision_categories[]" type="checkbox" value="human-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-human-rights">Human Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Improvement Notice" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-improvement-notice" name="tribunal_decision_categories[]" type="checkbox" value="improvement-notice"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-improvement-notice">Improvement Notice</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Interim Relief" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-interim-relief" name="tribunal_decision_categories[]" type="checkbox" value="interim-relief"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-interim-relief">Interim Relief</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Jurisdictional Points" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-jurisdictional-points" name="tribunal_decision_categories[]" type="checkbox" value="jurisdictional-points"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-jurisdictional-points">Jurisdictional Points</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Maternity and Pregnancy Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-maternity-and-pregnancy-rights" name="tribunal_decision_categories[]" type="checkbox" value="maternity-and-pregnancy-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-maternity-and-pregnancy-rights">Maternity and Pregnancy Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Minimum Wage" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-minimum-wage" name="tribunal_decision_categories[]" type="checkbox" value="national-minimum-wage"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-minimum-wage">National Minimum Wage</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Security" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-security" name="tribunal_decision_categories[]" type="checkbox" value="national-security"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-security">National Security</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Notice Appeal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-notice-appeal" name="tribunal_decision_categories[]" type="checkbox" value="notice-appeal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-notice-appeal">Notice Appeal</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Parental and Maternity Leave" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-parental-and-maternity-leave" name="tribunal_decision_categories[]" type="checkbox" value="parental-and-maternity-leave"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-parental-and-maternity-leave">Parental and Maternity Leave</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Part Time Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-part-time-workers" name="tribunal_decision_categories[]" type="checkbox" value="part-time-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-part-time-workers">Part Time Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Pension" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-pension" name="tribunal_decision_categories[]" type="checkbox" value="pension"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-pension">Pension</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Practice and Procedure Issues" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-practice-and-procedure-issues" name="tribunal_decision_categories[]" type="checkbox" value="practice-and-procedure-issues"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-practice-and-procedure-issues">Practice and Procedure Issues</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Protective Award" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-protective-award" name="tribunal_decision_categories[]" type="checkbox" value="protective-award"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-protective-award">Protective Award</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Public Interest Disclosure" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-public-interest-disclosure" name="tribunal_decision_categories[]" type="checkbox" value="public-interest-disclosure"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-public-interest-disclosure">Public Interest Disclosure</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Race Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-race-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="race-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-race-discrimination">Race Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Redundancy" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-redundancy" name="tribunal_decision_categories[]" type="checkbox" value="redundancy"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-redundancy">Redundancy</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Religion or Belief Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-religion-or-belief-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="religion-or-belief-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-religion-or-belief-discrimination">Religion or Belief Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Renumeration" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-renumeration" name="tribunal_decision_categories[]" type="checkbox" value="renumeration"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-renumeration">Renumeration</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reorganisation" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reorganisation" name="tribunal_decision_categories[]" type="checkbox" value="reorganisation"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reorganisation">Reorganisation</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reserved Forces Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reserved-forces-act" name="tribunal_decision_categories[]" type="checkbox" value="reserved-forces-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reserved-forces-act">Reserved Forces Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Right To Be Accompanied" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-right-to-be-accompanied" name="tribunal_decision_categories[]" type="checkbox" value="right-to-be-accompanied"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-right-to-be-accompanied">Right To Be Accompanied</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Rights on Insolvency" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-rights-on-insolvency" name="tribunal_decision_categories[]" type="checkbox" value="rights-on-insolvency"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-rights-on-insolvency">Rights on Insolvency</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sex Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sex-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="sex-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sex-discrimination">Sex Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sexual Orientation Discrimination/Transexualism" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sexual-orientation-discrimination-transexualism" name="tribunal_decision_categories[]" type="checkbox" value="sexual-orientation-discrimination-transexualism"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sexual-orientation-discrimination-transexualism">Sexual Orientation Discrimination/Transexualism</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Statutory Discipline and Grievance Procedures" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-statutory-discipline-and-grievance-procedures" name="tribunal_decision_categories[]" type="checkbox" value="statutory-discipline-and-grievance-procedures"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-statutory-discipline-and-grievance-procedures">Statutory Discipline and Grievance Procedures</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Tax" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-tax" name="tribunal_decision_categories[]" type="checkbox" value="tax"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-tax">Tax</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Temporary Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-temporary-employment" name="tribunal_decision_categories[]" type="checkbox" value="temporary-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-temporary-employment">Temporary Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Limits" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-limits" name="tribunal_decision_categories[]" type="checkbox" value="time-limits"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-limits">Time Limits</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Off" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-off" name="tribunal_decision_categories[]" type="checkbox" value="time-off"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-off">Time Off</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time to Train" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-to-train" name="tribunal_decision_categories[]" type="checkbox" value="time-to-train"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-to-train">Time to Train</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Membership" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-membership" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-membership"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-membership">Trade Union Membership</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-rights" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-rights">Trade Union Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Transfer of Undertakings" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-transfer-of-undertakings" name="tribunal_decision_categories[]" type="checkbox" value="transfer-of-undertakings"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-transfer-of-undertakings">Transfer of Undertakings</label>
#  </li> <li class="govuk-checkboxes__item">
# ...
#  <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
#  <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#          Maybe
#  </a> <ul class="gem-c-feedback__option-list">
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
#  <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            Yes <span class="visually-hidden">this page is useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
#  <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            No <span class="visually-hidden">this page is not useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
#  <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#            Is there anything wrong with this page?
#  </a> </li>
#  </ul>
#  </div>
#  <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#      Thank you for your feedback
#    </div>
#  </div>
#  <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
#  <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
#  <input name="url" type="hidden" value="https://www.gov.uk/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-fa4d6848">
#    What were you doing?
#  </label>
#  <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-fa4d6848" name="what_doing" type="text"/>
#  </div>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-5c3f3a0c">
#    What went wrong?
#  </label>
#  <input class="gem-c-input govuk-input" id="input-5c3f3a0c" name="what_wrong" type="text"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send</button>
#  </div>
#  </div>
#  </form>
#  <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
#  <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
#  <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
#  <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
#  <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-9f3fe982">
#    Email address
#  </label>
#  <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-9f3fe982" name="email_survey_signup[email_address]" type="email"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  <footer class="group js-footer" id="footer" role="contentinfo">
#  <div class="govuk-width-container">
#  <div class="footer-container govuk-main-wrapper">
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Transition period</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                 Find out what it means for you
#              </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Services and information</h2>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                    Benefits
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                    Births, deaths, marriages and care
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                    Business and self-employed
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                    Childcare and parenting
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                    Citizenship and living in the UK
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                    Crime, justice and the law
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                    Disabled people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                    Driving and transport
#                  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                    Education and learning
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                    Employing people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                    Environment and countryside
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                    Housing and local services
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                    Money and tax
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                    Passports, travel and living abroad
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                    Visas and immigration
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                    Working, jobs and pensions
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  <h2>Departments and policy</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#                How government works
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#                Departments
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#                Worldwide
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#                Services
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#                Guidance and regulation
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#                News and communications
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#                Research and statistics
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#                Policy papers and consultations
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#                Transparency and freedom of information releases
#              </a>
#  </li>
#  </ul>
#  </div>
#  <hr/>
#  </div>
#  <div class="footer-meta">
#  <div class="footer-meta-inner">
#  <h2 class="visuallyhidden">Support links</h2>
#  <ul>
#  <li><a class="govuk-link" href="/help">Help</a></li>
#  <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
#  <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
#  <li><a class="govuk-link" href="/contact">Contact</a></li>
#  <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
#  <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
#  <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
#  <li>
#      Built by the
#      <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#        Government Digital Service
#      </a>
#  </li>
#  </ul>
#  <div class="open-government-licence">
#  <p class="logo">
#  <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                      Open Government Licence
#                    </a>
#  </p>
#  <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
#  </div>
#  </div>
#  <div class="copyright">
#  <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                   © Crown copyright
#                </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </footer>
#  <div class="app-error hidden" id="global-app-error"></div>
#  <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
#  <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
#  <script src="https://assets.publishing.service.gov.uk/finder-frontend/application-24e2befd8fdd002b4bf83ea458d3d95a87ab18f97cfc6f002560bddcfad8e68a.js"></script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"SearchResultsPage","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions"},"headline":"Employment tribunal decisions","datePublished":"2017-02-08T16:15:17.000+00:00","dateModified":"2020-01-21T14:54:42.000+00:00","description":"Find decisions on Employment Tribunal cases in England, Wales and Scotland.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"]}
#  </script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}}]}
#  </script>
#  </body>
#  </html>,
#  '\n']

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.Comment,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[4]

# %%
body = list(html.children)[5]

# %%
list(body.children)
# Out:
# ['\n',
#  <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>,
#  '\n',
#  <div id="skiplink-container">
#  <div>
#  <a class="skiplink govuk-link" href="#content">Skip to main content</a>
#  </div>
#  </div>,
#  '\n',
#  <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
#  <div class="gem-c-cookie-banner__wrapper govuk-width-container">
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-cookie-banner__message">
#  <span class="govuk-heading-m">Tell us whether you accept cookies</span>
#  <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
#  </div>
#  <div class="gem-c-cookie-banner__buttons">
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
#  </div>
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
#  <p class="gem-c-cookie-banner__confirmation-message">
#        You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#      </p>
#  <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
#  </div>
#  </div>,
#  '\n',
#  <header class="" id="global-header" role="banner">
#  <div class="header-wrapper">
#  <div class="header-global">
#  <div class="header-logo">
#  <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
#  <span class="govuk-header__logotype">
#  <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
#  <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#  </path>
#  <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
#  </svg>
#  <span class="govuk-header__logotype-text">
#                    GOV.UK
#                  </span>
#  </span>
#  </a>
#  </div>
#  <a class="search-toggle js-header-toggle" href="#search">Search</a>
#  <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
#  <div class="content govuk-clearfix">
#  <label for="site-search-text">Search</label>
#  <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
#  <input class="submit" type="submit" value="Search"/>
#  </div>
#  </form>
#  </div>
#  </div>
#  </header>,
#  '\n',
#  <div id="user-satisfaction-survey-container"></div>,
#  '\n',
#  <div id="global-header-bar"></div>,
#  '\n',
#  '[if gt IE 7]><!',
#  '\n',
#  <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
#  <div class="global-bar-message-container">
#  <p class="global-bar-message">
#  <span class="global-bar-title">The UK has left the EU</span>
#  <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
#  </p>
#  <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
#  </div>
#  </div>,
#  '\n',
#  '<![endif]',
#  '\n',
#  <div id="wrapper">
#  <main class="finder-frontend-content" id="content">
#  <div class="finder-frontend">
#  <form action="/employment-tribunal-decisions" class="js-live-search-form" method="get">
#  <input name="parent" type="hidden" value=""/>
#  <div class="govuk-width-container">
#  <div class="gem-c-phase-banner govuk-phase-banner">
#  <p class="govuk-phase-banner__content">
#  <strong class="govuk-tag govuk-phase-banner__content__tag">beta</strong>
#  <span class="govuk-phase-banner__text">This part of GOV.UK is being rebuilt – <a class="govuk-link" href="/help/beta">find out what beta means</a></span>
#  </p>
#  </div>
#  <div class="gem-c-contextual-breadcrumbs">
#  <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
#  <ol class="govuk-breadcrumbs__list">
#  <li aria-current="false" class="govuk-breadcrumbs__list-item">
#  <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
#  </li>
#  </ol>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
#  <h1 class="gem-c-title__text">
#      Employment tribunal decisions
#    </h1>
#  </div>
#  <div class="gem-c-metadata" data-module="gem-toggle">
#  <dl data-module="track-click">
#  <dt class="gem-c-metadata__term">From:</dt>
#  <dd class="gem-c-metadata__definition">
#  <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="govuk-grid-column-two-thirds">
#  <div class="metadata-summary">
#  <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
#  <p>Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.</p>
#  <p>If the decision was made before February 2017, contact <a href="https://courttribunalfinder.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a> for cases in England or Wales, or <a href="https://courttribunalfinder.service.gov.uk/courts/glasgow-tribunal-hearing-centre-eagle-building">Glasgow Tribunal Hearing Centre</a> for cases in Scotland.</p>
#  <p>Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-width-container">
#  <div class="govuk-grid-row">
#  <div aria-label="Employment tribunal decisions" class="govuk-grid-column-one-third" role="search">
#  <div class="filter-form">
#  <div id="keywords">
#  <div class="gem-c-search gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
#  <label class="gem-c-search__label" for="finder-keyword-search">
#              Search <span class="govuk-visually-hidden">Employment tribunal decisions</span>
#  </label>
#  <div class="gem-c-search__item-wrapper">
#  <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
#  <div class="gem-c-search__item gem-c-search__submit-wrapper">
#  <button class="gem-c-search__submit" type="submit">Search</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <button class="app-c-button-as-link app-mobile-filters-link js-show-mobile-filters" data-module="track-click" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#          Filter <span class="govuk-visually-hidden"> results</span>
#  <span class="js-selected-filter-count"></span>
#  </button>
#  <div data-module="track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
#  <a class="gem-c-skip-link govuk-skip-link" href="#js-results">Skip to results</a>
#  </div>
#  <div class="facets" data-module="mobile-filters-modal" id="facet-wrapper">
#  <div class="facets__box">
#  <div class="facets__header">
#  <h1 class="gem-c-title__text">Filter</h1>
#  <button class="app-c-button-as-link facets__return-link js-close-filters" type="button">
#              Return to results
#            </button>
#  </div>
#  <div class="facets__content">
#  <div class="app-c-option-select" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-country">Country</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-1aa5b9a8">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Country</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">England and Wales</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">Scotland</label>
#  </li>
#  </ul>
#  </fieldset>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="app-c-option-select" data-closed-on-load="true" data-input-aria-controls="js-search-results-info" data-module="option-select">
#  <h2 class="app-c-option-select__heading js-container-heading">
#  <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">Jurisdiction code</span>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div aria-labelledby="option-select-title-jurisdiction-code" class="app-c-option-select__container js-options-container" id="tribunal_decision_categories" role="group" tabindex="-1">
#  <div class="app-c-option-select__container-inner js-auto-height-inner">
#  <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="govuk-checkboxes" id="checkboxes-759922cf">
#  <fieldset class="govuk-fieldset">
#  <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Jurisdiction code</legend>
#  <ul class="govuk-checkboxes gem-c-checkboxes__list">
#  <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Age Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-age-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="age-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-age-discrimination">Age Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Agency Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-agency-workers" name="tribunal_decision_categories[]" type="checkbox" value="agency-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-agency-workers">Agency Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Blacklisting Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-blacklisting-regulations" name="tribunal_decision_categories[]" type="checkbox" value="blacklisting-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-blacklisting-regulations">Blacklisting Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Breach of Contract" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-breach-of-contract" name="tribunal_decision_categories[]" type="checkbox" value="breach-of-contract"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-breach-of-contract">Breach of Contract</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Central Arbitration Committee (CAC)" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-central-arbitration-committee-cac" name="tribunal_decision_categories[]" type="checkbox" value="central-arbitration-committee-cac"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-central-arbitration-committee-cac">Central Arbitration Committee (CAC)</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Certification Officer" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-certification-officer" name="tribunal_decision_categories[]" type="checkbox" value="certification-officer"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-certification-officer">Certification Officer</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Contract of Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-contract-of-employment" name="tribunal_decision_categories[]" type="checkbox" value="contract-of-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-contract-of-employment">Contract of Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Disability Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-disability-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="disability-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-disability-discrimination">Disability Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Employment Agencies Act 1973" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-employment-agencies-act-1973" name="tribunal_decision_categories[]" type="checkbox" value="employment-agencies-act-1973"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-employment-agencies-act-1973">Employment Agencies Act 1973</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Equal Pay Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-equal-pay-act" name="tribunal_decision_categories[]" type="checkbox" value="equal-pay-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-equal-pay-act">Equal Pay Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="European Material" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-european-material" name="tribunal_decision_categories[]" type="checkbox" value="european-material"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-european-material">European Material</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Fixed Term Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-fixed-term-regulations" name="tribunal_decision_categories[]" type="checkbox" value="fixed-term-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-fixed-term-regulations">Fixed Term Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Flexible Working" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-flexible-working" name="tribunal_decision_categories[]" type="checkbox" value="flexible-working"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-flexible-working">Flexible Working</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Harassment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-harassment" name="tribunal_decision_categories[]" type="checkbox" value="harassment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-harassment">Harassment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Health &amp; Safety" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-health-safety" name="tribunal_decision_categories[]" type="checkbox" value="health-safety"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-health-safety">Health &amp; Safety</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Human Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-human-rights" name="tribunal_decision_categories[]" type="checkbox" value="human-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-human-rights">Human Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Improvement Notice" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-improvement-notice" name="tribunal_decision_categories[]" type="checkbox" value="improvement-notice"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-improvement-notice">Improvement Notice</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Interim Relief" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-interim-relief" name="tribunal_decision_categories[]" type="checkbox" value="interim-relief"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-interim-relief">Interim Relief</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Jurisdictional Points" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-jurisdictional-points" name="tribunal_decision_categories[]" type="checkbox" value="jurisdictional-points"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-jurisdictional-points">Jurisdictional Points</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Maternity and Pregnancy Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-maternity-and-pregnancy-rights" name="tribunal_decision_categories[]" type="checkbox" value="maternity-and-pregnancy-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-maternity-and-pregnancy-rights">Maternity and Pregnancy Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Minimum Wage" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-minimum-wage" name="tribunal_decision_categories[]" type="checkbox" value="national-minimum-wage"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-minimum-wage">National Minimum Wage</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="National Security" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-national-security" name="tribunal_decision_categories[]" type="checkbox" value="national-security"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-national-security">National Security</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Notice Appeal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-notice-appeal" name="tribunal_decision_categories[]" type="checkbox" value="notice-appeal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-notice-appeal">Notice Appeal</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Parental and Maternity Leave" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-parental-and-maternity-leave" name="tribunal_decision_categories[]" type="checkbox" value="parental-and-maternity-leave"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-parental-and-maternity-leave">Parental and Maternity Leave</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Part Time Workers" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-part-time-workers" name="tribunal_decision_categories[]" type="checkbox" value="part-time-workers"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-part-time-workers">Part Time Workers</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Pension" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-pension" name="tribunal_decision_categories[]" type="checkbox" value="pension"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-pension">Pension</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Practice and Procedure Issues" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-practice-and-procedure-issues" name="tribunal_decision_categories[]" type="checkbox" value="practice-and-procedure-issues"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-practice-and-procedure-issues">Practice and Procedure Issues</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Protective Award" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-protective-award" name="tribunal_decision_categories[]" type="checkbox" value="protective-award"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-protective-award">Protective Award</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Public Interest Disclosure" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-public-interest-disclosure" name="tribunal_decision_categories[]" type="checkbox" value="public-interest-disclosure"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-public-interest-disclosure">Public Interest Disclosure</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Race Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-race-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="race-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-race-discrimination">Race Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Redundancy" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-redundancy" name="tribunal_decision_categories[]" type="checkbox" value="redundancy"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-redundancy">Redundancy</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Religion or Belief Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-religion-or-belief-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="religion-or-belief-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-religion-or-belief-discrimination">Religion or Belief Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Renumeration" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-renumeration" name="tribunal_decision_categories[]" type="checkbox" value="renumeration"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-renumeration">Renumeration</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reorganisation" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reorganisation" name="tribunal_decision_categories[]" type="checkbox" value="reorganisation"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reorganisation">Reorganisation</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Reserved Forces Act" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-reserved-forces-act" name="tribunal_decision_categories[]" type="checkbox" value="reserved-forces-act"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-reserved-forces-act">Reserved Forces Act</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Right To Be Accompanied" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-right-to-be-accompanied" name="tribunal_decision_categories[]" type="checkbox" value="right-to-be-accompanied"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-right-to-be-accompanied">Right To Be Accompanied</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Rights on Insolvency" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-rights-on-insolvency" name="tribunal_decision_categories[]" type="checkbox" value="rights-on-insolvency"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-rights-on-insolvency">Rights on Insolvency</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sex Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sex-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="sex-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sex-discrimination">Sex Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Sexual Orientation Discrimination/Transexualism" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-sexual-orientation-discrimination-transexualism" name="tribunal_decision_categories[]" type="checkbox" value="sexual-orientation-discrimination-transexualism"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-sexual-orientation-discrimination-transexualism">Sexual Orientation Discrimination/Transexualism</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Statutory Discipline and Grievance Procedures" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-statutory-discipline-and-grievance-procedures" name="tribunal_decision_categories[]" type="checkbox" value="statutory-discipline-and-grievance-procedures"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-statutory-discipline-and-grievance-procedures">Statutory Discipline and Grievance Procedures</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Tax" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-tax" name="tribunal_decision_categories[]" type="checkbox" value="tax"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-tax">Tax</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Temporary Employment" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-temporary-employment" name="tribunal_decision_categories[]" type="checkbox" value="temporary-employment"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-temporary-employment">Temporary Employment</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Limits" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-limits" name="tribunal_decision_categories[]" type="checkbox" value="time-limits"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-limits">Time Limits</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time Off" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-off" name="tribunal_decision_categories[]" type="checkbox" value="time-off"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-off">Time Off</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Time to Train" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-time-to-train" name="tribunal_decision_categories[]" type="checkbox" value="time-to-train"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-time-to-train">Time to Train</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Membership" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-membership" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-membership"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-membership">Trade Union Membership</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Trade Union Rights" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-trade-union-rights" name="tribunal_decision_categories[]" type="checkbox" value="trade-union-rights"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-trade-union-rights">Trade Union Rights</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Transfer of Undertakings" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-transfer-of-undertakings" name="tribunal_decision_categories[]" type="checkbox" value="transfer-of-undertakings"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-transfer-of-undertakings">Transfer of Undertakings</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Unfair Dismissal" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-unfair-dismissal" name="tribunal_decision_categories[]" type="checkbox" value="unfair-dismissal"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-unfair-dismissal">Unfair Dismissal</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Unlawful Deduction from Wages" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-unlawful-deduction-from-wages" name="tribunal_decision_categories[]" type="checkbox" value="unlawful-deduction-from-wages"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-unlawful-deduction-from-wages">Unlawful Deduction from Wages</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Victimisation Discrimination" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-victimisation-discrimination" name="tribunal_decision_categories[]" type="checkbox" value="victimisation-discrimination"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-victimisation-discrimination">Victimisation Discrimination</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Working Time Regulations" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-working-time-regulations" name="tribunal_decision_categories[]" type="checkbox" value="working-time-regulations"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-working-time-regulations">Working Time Regulations</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Written Pay Statement" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-written-pay-statement" name="tribunal_decision_categories[]" type="checkbox" value="written-pay-statement"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-written-pay-statement">Written Pay Statement</label>
#  </li> <li class="govuk-checkboxes__item">
#  <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Jurisdiction code" data-track-category="filterClicked" data-track-label="Written Statements" data-uncheck-track-category="filterRemoved" id="tribunal_decision_categories-written-statements" name="tribunal_decision_categories[]" type="checkbox" value="written-statements"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_categories-written-statements">Written Statements</label>
#  </li>
#  </ul>
#  </fieldset>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="app-c-expander" data-module="expander" data-open-on-load="false">
#  <h2 class="app-c-expander__heading">
#  <span class="app-c-expander__title js-toggle">Date</span>
#  <svg aria-hidden="true" class="app-c-expander__icon app-c-expander__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
#  <svg aria-hidden="true" class="app-c-expander__icon app-c-expander__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
#  </h2>
#  <div class="app-c-expander__content js-content" id="expander-content-11f8417b">
#  <div class="app-c-date-filter govuk-!-margin-bottom-0" data-module="enable-aria-controls" id="tribunal_decision_decision_date">
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="tribunal_decision_decision_date[from]">
#    Decision date after
#  </label>
#  <div class="gem-c-hint govuk-hint govuk-!-margin-bottom-3" id="hint-696ff5ae">
#    For example, 2005 or 21/11/2014
#  </div>
#  <input aria-controls="js-search-results-info" aria-describedby="hint-696ff5ae" class="gem-c-input govuk-input" id="tribunal_decision_decision_date[from]" name="tribunal_decision_decision_date[from]" type="text" value=""/>
#  </div>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="tribunal_decision_decision_date[to]">
#    Decision date before
#  </label>
#  <div class="gem-c-hint govuk-hint govuk-!-margin-bottom-3" id="hint-e691b56b">
#    For example, 2005 or 21/11/2014
#  </div>
#  <input aria-controls="js-search-results-info" aria-describedby="hint-e691b56b" class="gem-c-input govuk-input" id="tribunal_decision_decision_date[to]" name="tribunal_decision_decision_date[to]" type="text" value=""/>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="facets__tags-block js-mobile-facet-tag-block" data-module="remove-filter">
#  <span class="govuk-visually-hidden">
#      54,673 decisions
#
#    </span>
#  <div class="facet-tags" data-module="track-click">
#  </div>
#  </div>
# ...
#  <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#          Maybe
#  </a> <ul class="gem-c-feedback__option-list">
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
#  <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            Yes <span class="visually-hidden">this page is useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
#  <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            No <span class="visually-hidden">this page is not useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
#  <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#            Is there anything wrong with this page?
#  </a> </li>
#  </ul>
#  </div>
#  <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#      Thank you for your feedback
#    </div>
#  </div>
#  <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
#  <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
#  <input name="url" type="hidden" value="https://www.gov.uk/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-fa4d6848">
#    What were you doing?
#  </label>
#  <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-fa4d6848" name="what_doing" type="text"/>
#  </div>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-5c3f3a0c">
#    What went wrong?
#  </label>
#  <input class="gem-c-input govuk-input" id="input-5c3f3a0c" name="what_wrong" type="text"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send</button>
#  </div>
#  </div>
#  </form>
#  <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
#  <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
#  <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
#  <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
#  <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions?page=1"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-9f3fe982">
#    Email address
#  </label>
#  <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-9f3fe982" name="email_survey_signup[email_address]" type="email"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>,
#  '\n',
#  <footer class="group js-footer" id="footer" role="contentinfo">
#  <div class="govuk-width-container">
#  <div class="footer-container govuk-main-wrapper">
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Transition period</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                 Find out what it means for you
#              </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Services and information</h2>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                    Benefits
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                    Births, deaths, marriages and care
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                    Business and self-employed
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                    Childcare and parenting
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                    Citizenship and living in the UK
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                    Crime, justice and the law
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                    Disabled people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                    Driving and transport
#                  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                    Education and learning
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                    Employing people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                    Environment and countryside
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                    Housing and local services
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                    Money and tax
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                    Passports, travel and living abroad
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                    Visas and immigration
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                    Working, jobs and pensions
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  <h2>Departments and policy</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#                How government works
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#                Departments
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#                Worldwide
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#                Services
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#                Guidance and regulation
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#                News and communications
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#                Research and statistics
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#                Policy papers and consultations
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#                Transparency and freedom of information releases
#              </a>
#  </li>
#  </ul>
#  </div>
#  <hr/>
#  </div>
#  <div class="footer-meta">
#  <div class="footer-meta-inner">
#  <h2 class="visuallyhidden">Support links</h2>
#  <ul>
#  <li><a class="govuk-link" href="/help">Help</a></li>
#  <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
#  <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
#  <li><a class="govuk-link" href="/contact">Contact</a></li>
#  <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
#  <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
#  <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
#  <li>
#      Built by the
#      <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#        Government Digital Service
#      </a>
#  </li>
#  </ul>
#  <div class="open-government-licence">
#  <p class="logo">
#  <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                      Open Government Licence
#                    </a>
#  </p>
#  <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
#  </div>
#  </div>
#  <div class="copyright">
#  <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                   © Crown copyright
#                </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </footer>,
#  '\n',
#  <div class="app-error hidden" id="global-app-error"></div>,
#  '\n',
#  <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>,
#  '\n',
#  <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>,
#  '\n',
#  <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>,
#  '\n',
#  <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>,
#  '\n',
#  <script src="https://assets.publishing.service.gov.uk/finder-frontend/application-24e2befd8fdd002b4bf83ea458d3d95a87ab18f97cfc6f002560bddcfad8e68a.js"></script>,
#  <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"SearchResultsPage","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions"},"headline":"Employment tribunal decisions","datePublished":"2017-02-08T16:15:17.000+00:00","dateModified":"2020-01-21T14:54:42.000+00:00","description":"Find decisions on Employment Tribunal cases in England, Wales and Scotland.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"]}
#  </script>,
#  <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}}]}
#  </script>,
#  '\n']

# %%
cases = list(soup.find_all("li", class_="gem-c-document-list__item"))

# %%
cases[0].get_text()
# Out:
# '\nMs A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019\nEmployment Tribunal decision.\n\n\n                  Decided: 10 December 2019\n\n\n'

# %%
cases[0].find("a")['data-ecommerce-path']
# Out:
# '/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019'

# %%
cases[0].find("a")['href']
# Out:
# '/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019'

# %%
# retrieves the webpage for the specific court case
details = get_html_data("https://www.gov.uk/"+cases[0].find("a")['href'])

# %%
details
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]--><!--[if gt IE 8]><!--><html lang="en">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Employment Tribunal decision." property="og:description"/>
# <meta content="Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019" property="og:title"/>
# <meta content="https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="GOV.UK" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Employment Tribunal decision." name="description"/>
# <meta content="courts-sentencing-tribunals" name="govuk:taxon-slugs"/>
# <meta content="courts-sentencing-tribunals" name="govuk:taxon-slug"/>
# <meta content="357110bb-cbc5-4708-9711-1b26e6c63e86" name="govuk:taxon-ids"/>
# <meta content="357110bb-cbc5-4708-9711-1b26e6c63e86" name="govuk:taxon-id"/>
# <meta content="crime-justice-and-law" name="govuk:themes"/>
# <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
# <meta content="5ac38f52-0042-40a6-863d-517050b8164a" name="govuk:content-id"/>
# <meta content="specialist_document" name="govuk:schema-name"/>
# <meta content="specialist-publisher" name="govuk:publishing-application"/>
# <meta content="employment_tribunal_decision" name="govuk:format"/>
# <meta content="2iKI7jhIyuFOUVZ48DDXgdZPUaTK5DObVEMjfR5nRGshe5gGhu6KgyD4ppFcUqoCvJOArvhmgyCu1bQ4bmY9EQ==" name="csrf-token"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta charset="utf-8"/>
# <title lang="en">
#       Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - GOV.UK
#   </title>
# <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
# <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
# <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
# <meta content="#0b0c0c" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/core-layout-1924d57f4bba2603a29dda66a0fb53ded6bc766e697e13c27b52db13ddef3a7b.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/core-layout-ie8-40c60d07866c397b92055d03e2ba718d212ede58a127f1f61696ab648d8b123d.css" /><script>var ieVersion = 8;</script><![endif]-->
# <link href="https://assets.publishing.service.gov.uk/static/core-layout-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
# <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js"></script>
# <script>
#       if (GOVUK.globalBarInit) {
#         window.GOVUK.globalBarInit.init()
#       }
#     </script>
# <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
# <link href="https://assets.publishing.service.gov.uk/government-frontend/application-c4faf033b8bda5f85672660321358500e2430ae28600bf1b62d2858f93355911.css" media="screen" rel="stylesheet"/>
# <link href="https://assets.publishing.service.gov.uk/government-frontend/print-75909aa8c79ec8aa897d6e3bd44031259a95acfefd954436144a38f750771ffc.css" media="print" rel="stylesheet"/>
# <link href="https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" rel="canonical"/>
# <meta content="government-frontend" name="govuk:rendering-application"/>
# </head>
# <body>
# <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
# <div id="skiplink-container">
# <div>
# <a class="skiplink govuk-link" href="#content">Skip to main content</a>
# </div>
# </div>
# <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
# <div class="gem-c-cookie-banner__wrapper govuk-width-container">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-cookie-banner__message">
# <span class="govuk-heading-m">Tell us whether you accept cookies</span>
# <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
# </div>
# <div class="gem-c-cookie-banner__buttons">
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
# </div>
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
# <p class="gem-c-cookie-banner__confirmation-message">
#       You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#     </p>
# <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
# </div>
# </div>
# <header class="" id="global-header" role="banner">
# <div class="header-wrapper">
# <div class="header-global">
# <div class="header-logo">
# <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
# <span class="govuk-header__logotype">
# <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
# <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
# </path>
# <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
# </svg>
# <span class="govuk-header__logotype-text">
#                   GOV.UK
#                 </span>
# </span>
# </a>
# </div>
# <a class="search-toggle js-header-toggle" href="#search">Search</a>
# <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
# <div class="content govuk-clearfix">
# <label for="site-search-text">Search</label>
# <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
# <input class="submit" type="submit" value="Search"/>
# </div>
# </form>
# </div>
# </div>
# </header>
# <div id="user-satisfaction-survey-container"></div>
# <div id="global-header-bar"></div>
# <!--[if gt IE 7]><!-->
# <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
# <div class="global-bar-message-container">
# <p class="global-bar-message">
# <span class="global-bar-title">The UK has left the EU</span>
# <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
# </p>
# <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
# </div>
# </div>
# <!--<![endif]-->
# <div class="direction-ltr" id="wrapper">
# <div class="gem-c-contextual-breadcrumbs">
# <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
# <ol class="govuk-breadcrumbs__list">
# <li aria-current="false" class="govuk-breadcrumbs__list-item">
# <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
# </li>
# <li aria-current="false" class="govuk-breadcrumbs__list-item">
# <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="2" data-track-category="breadcrumbClicked" data-track-label="/employment-tribunal-decisions" data-track-options='{"dimension28":"2","dimension29":"Employment tribunal decisions"}' href="/employment-tribunal-decisions">Employment tribunal decisions</a>
# </li>
# </ol>
# </div>
# </div>
# <main class="specialist-document" id="content" lang="en" role="main">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds responsive-top-margin">
# <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
# <h1 class="gem-c-title__text gem-c-title__text--long">
#     Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019
#   </h1>
# </div>
# </div>
# <div class="govuk-grid-column-two-thirds">
# <p class="gem-c-lead-paragraph">Employment Tribunal decision.</p>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="metadata-logo-wrapper">
# <div class="govuk-grid-column-two-thirds metadata-column">
# <div class="app-c-publisher-metadata" lang="en">
# <div class="app-c-published-dates" lang="en">
#     Published 14 February 2020
# </div>
# <div class="app-c-publisher-metadata__other">
# <dl data-module="track-click">
# <dt class="app-c-publisher-metadata__term">
#               From:
#             </dt>
# <dd class="app-c-publisher-metadata__definition" data-module="gem-toggle">
# <span class="app-c-publisher-metadata__definition-sentence">
# <a class="govuk-link" href="/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a class="govuk-link" href="/courts-tribunals/employment-tribunal">Employment Tribunal</a>
# </span>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# </div>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="app-c-important-metadata app-c-important-metadata--bottom-margin">
# <dl data-module="track-click">
# <dt class="app-c-important-metadata__term">Decision date: </dt>
# <dd class="app-c-important-metadata__definition">10 December 2019</dd>
# <dt class="app-c-important-metadata__term">Country: </dt>
# <dd class="app-c-important-metadata__definition"><a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_country%5B%5D=england-and-wales">England and Wales</a></dd>
# <dt class="app-c-important-metadata__term">Jurisdiction code: </dt>
# <dd class="app-c-important-metadata__definition">
# <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=health-safety">Health &amp; Safety</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=public-interest-disclosure">Public Interest Disclosure</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=sex-discrimination">Sex Discrimination</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=unfair-dismissal">Unfair Dismissal</a>
# </dd>
# </dl>
# </div>
# <div class="app-c-contents-list-with-body" id="contents">
# <div class="responsive-bottom-margin">
# <div class="gem-c-govspeak govuk-govspeak direction-ltr" data-module="govspeak">
# <p>Read the full decision in  <span class="attachment-inline" id="attachment_f033a33b-568e-4985-95dd-6caca89c6f07"><a href="https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf">Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal</a></span>.</p>
# </div>
# </div>
# <div class="responsive-bottom-margin">
# <div class="app-c-published-dates" lang="en">
#     Published 14 February 2020
# </div>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# <div class="gem-c-contextual-sidebar">
# </div>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-contextual-footer">
# <div class="gem-c-related-navigation">
# <nav aria-labelledby="related-nav-topics-c257d08a" class="gem-c-related-navigation__nav-section" data-module="gem-toggle" role="navigation">
# <h2 class="gem-c-related-navigation__sub-heading gem-c-related-navigation__sub-heading--footer" data-track-count="footerRelatedItemSection" id="related-nav-topics-c257d08a">Explore the topic</h2>
# <ul class="gem-c-related-navigation__link-list" data-module="track-click">
# <li class="gem-c-related-navigation__link"><a class="gem-c-related-navigation__section-link gem-c-related-navigation__section-link--footer" data-track-action="1.1 Explore the topic" data-track-category="relatedLinkClicked" data-track-label="/crime-justice-and-law/courts-sentencing-tribunals" data-track-options='{"dimension28":"1","dimension29":"Courts, sentencing and tribunals"}' href="/crime-justice-and-law/courts-sentencing-tribunals">Courts, sentencing and tribunals</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="gem-c-feedback gem-c-feedback--top-margin" data-module="feedback">
# <div class="gem-c-feedback__prompt gem-c-feedback__js-show js-prompt" tabindex="-1">
# <div class="gem-c-feedback__js-prompt-questions js-prompt-questions">
# <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
# <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#         Maybe
# </a> <ul class="gem-c-feedback__option-list">
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
# <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           Yes <span class="visually-hidden">this page is useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
# <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           No <span class="visually-hidden">this page is not useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
# <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#           Is there anything wrong with this page?
# </a> </li>
# </ul>
# </div>
# <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#     Thank you for your feedback
#   </div>
# </div>
# <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
# <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
# <input name="url" type="hidden" value="https://www.gov.uk//employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-16284a1f">
#   What were you doing?
# </label>
# <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-16284a1f" name="what_doing" type="text"/>
# </div>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-fb6da8b7">
#   What went wrong?
# </label>
# <input class="gem-c-input govuk-input" id="input-fb6da8b7" name="what_wrong" type="text"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send</button>
# </div>
# </div>
# </form>
# <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
# <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
# <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
# <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
# <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-408e4758">
#   Email address
# </label>
# <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-408e4758" name="email_survey_signup[email_address]" type="email"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <footer class="group js-footer" id="footer" role="contentinfo">
# <div class="govuk-width-container">
# <div class="footer-container govuk-main-wrapper">
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Transition period</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                Find out what it means for you
#             </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Services and information</h2>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                   Benefits
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                   Births, deaths, marriages and care
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                   Business and self-employed
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                   Childcare and parenting
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                   Citizenship and living in the UK
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                   Crime, justice and the law
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                   Disabled people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                   Driving and transport
#                 </a>
# </li>
# </ul>
# </div>
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                   Education and learning
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                   Employing people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                   Environment and countryside
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                   Housing and local services
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                   Money and tax
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                   Passports, travel and living abroad
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                   Visas and immigration
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                   Working, jobs and pensions
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# <h2>Departments and policy</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#               How government works
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#               Departments
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#               Worldwide
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#               Services
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#               Guidance and regulation
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#               News and communications
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#               Research and statistics
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#               Policy papers and consultations
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#               Transparency and freedom of information releases
#             </a>
# </li>
# </ul>
# </div>
# <hr/>
# </div>
# <div class="footer-meta">
# <div class="footer-meta-inner">
# <h2 class="visuallyhidden">Support links</h2>
# <ul>
# <li><a class="govuk-link" href="/help">Help</a></li>
# <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
# <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
# <li><a class="govuk-link" href="/contact">Contact</a></li>
# <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
# <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
# <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
# <li>
#     Built by the
#     <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#       Government Digital Service
#     </a>
# </li>
# </ul>
# <div class="open-government-licence">
# <p class="logo">
# <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                     Open Government Licence
#                   </a>
# </p>
# <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
# </div>
# </div>
# <div class="copyright">
# <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                  © Crown copyright
#               </a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="app-error hidden" id="global-app-error"></div>
# <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
# <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
# <script src="https://assets.publishing.service.gov.uk/government-frontend/application-6323e1ed84f4f2ae6ee1cd2f5710c1527a5ce122b319d1b0ccb645554d2b1a05.js"></script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"Article","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"},"headline":"Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019","datePublished":"2020-02-14T14:56:29.000+00:00","dateModified":"2020-02-14T14:56:29.000+00:00","description":"Employment Tribunal decision.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"],"author":{"@type":"Organization","name":"HM Courts \u0026 Tribunals Service","url":"https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service"},"about":[{"@context":"http://schema.org","@type":"Thing","sameAs":"https://www.gov.uk/crime-justice-and-law/courts-sentencing-tribunals"}],"articleBody":"\u003cp\u003eRead the full decision in  \u003cspan id=\"attachment_f033a33b-568e-4985-95dd-6caca89c6f07\" class=\"attachment-inline\"\u003e\u003ca href=\"https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf\"\u003eMs A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal\u003c/a\u003e\u003c/span\u003e.\u003c/p\u003e\n"}
# </script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}},{"@type":"ListItem","position":2,"item":{"name":"Employment tribunal decisions","@id":"https://www.gov.uk/employment-tribunal-decisions"}}]}
# </script>
# </body>
# </html>

# %%
# the individual case pages seem to have the same structure as the government webpage. 
[type(item) for item in list(details.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.Comment,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %% [markdown]
# ## Now that we've messed around, let's get our first goal: retrieve the date for the first case on the first page

# %%
# get the first page
page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page=1")
soup = BeautifulSoup(page.content, 'html.parser')

cases = list(soup.find_all("li", class_="gem-c-document-list__item"))
case = cases[0]

# %%
case.get_text()
# Out:
# '\nMs A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019\nEmployment Tribunal decision.\n\n\n                  Decided: 10 December 2019\n\n\n'

# %%
str(case.get_text()).split('Decided: ')[1].split('\n')[0]
# Out:
# '10 December 2019'

# %% [markdown]
# That gives us the date of the first case on the first page. That was the easy part.

# %% [markdown]
# ## Next step: what else is in that first tag?

# %%
case
# Out:
# <li class="gem-c-document-list__item">
# <a class="gem-c-document-list__item-title gem-c-document-list__item-link" data-ecommerce-path="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" data-ecommerce-row="1" data-track-action="Employment tribunal decisions.1" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" data-track-options='{"dimension28":50,"dimension29":"Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019"}' href="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019">Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019</a>
# <p class="gem-c-document-list__item-description">Employment Tribunal decision.</p>
# <ul class="gem-c-document-list__item-metadata">
# <li class="gem-c-document-list__attribute">
#                   Decided: <time datetime="2019-12-10">10 December 2019</time>
# </li>
# </ul>
# </li>

# %% [markdown]
# Actually looks like rather than getting the date via the text, we can search for a datetime object.

# %%
case.find("time")['datetime']
# Out:
# '2019-12-10'

# %% [markdown]
# That's a lot easier!
# There doesn't seem to be much more information at this stage, so we will have to follow the url to the case page.

# %%
casepage = requests.get("https://www.gov.uk/"+case.find("a")['href'])
casesoup = BeautifulSoup(casepage.content, 'html.parser')

# %%
list(casesoup.children)
# Out:
# ['html',
#  '\n',
#  '[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]',
#  '[if gt IE 8]><!',
#  <html lang="en">
#  <!--<![endif]-->
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="Employment Tribunal decision." property="og:description"/>
#  <meta content="Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019" property="og:title"/>
#  <meta content="https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" property="og:url"/>
#  <meta content="article" property="og:type"/>
#  <meta content="GOV.UK" property="og:site_name"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="Employment Tribunal decision." name="description"/>
#  <meta content="courts-sentencing-tribunals" name="govuk:taxon-slugs"/>
#  <meta content="courts-sentencing-tribunals" name="govuk:taxon-slug"/>
#  <meta content="357110bb-cbc5-4708-9711-1b26e6c63e86" name="govuk:taxon-ids"/>
#  <meta content="357110bb-cbc5-4708-9711-1b26e6c63e86" name="govuk:taxon-id"/>
#  <meta content="crime-justice-and-law" name="govuk:themes"/>
#  <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
#  <meta content="5ac38f52-0042-40a6-863d-517050b8164a" name="govuk:content-id"/>
#  <meta content="specialist_document" name="govuk:schema-name"/>
#  <meta content="specialist-publisher" name="govuk:publishing-application"/>
#  <meta content="employment_tribunal_decision" name="govuk:format"/>
#  <meta content="pY0PIXzeNv8X+DGRYpCdmu6Q9Z77hjZ098tnkAjDs0vf/HI0qysSHDiIyI/qBnW201W3+8WjPBzFRmaWgWqdlw==" name="csrf-token"/>
#  <meta content="authenticity_token" name="csrf-param"/>
#  <meta charset="utf-8"/>
#  <title lang="en">
#        Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - GOV.UK
#    </title>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/govuk-template-c0b8ba8b1652aacad298d74f24752260187f538b50c40c2484f7f333cbc3cf2b.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/govuk-template-ie8-11027733d1abeac34c7bf14e37fea30366ad3a87cfd7f7a084de3a3b4b838412.css" /><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/govuk-template-print-1076519521c2fffbbf75ab3b0d3b32ee2d96ac7e9778f1cdfac1771eefd1a1c0.css" media="print" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/static/fonts-e9ec5a5f82e5c2a17927ce356e5a054cb28025ec1547ec5d00f5c98d2ec5e481.css" media="all" rel="stylesheet"/>
#  <!--[if lt IE 9]><script src="https://assets.publishing.service.gov.uk/static/ie-a4524544a53d57a7e259b4bb966b9c32557c98c920b77e52d09304642b68401a.js"></script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/favicon-8d811b8c3badbc0b0e2f6e25d3660a96cc0cca7993e6f32e98785f205fc40907.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link color="#0b0c0c" href="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown-de738c3fcce8ce2a91b67e89787090dc24a5cda0275ab6b75f6226c5b9619d3d.svg" rel="mask-icon"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-180x180-ea1cbb1cbbeddfff275dfa6e8e46b84cd530892df79dc4882a8f99b802b49a90.png" rel="apple-touch-icon" sizes="180x180"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-167x167-181e404a50c572923285fb83f0fbd78da6b4e38e3ce52f8e6b8e29da8586450a.png" rel="apple-touch-icon" sizes="167x167"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-152x152-02457fcdcee8d309276305af2233d41bfb8fd055e855727d355e61bce7ffa9bb.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://assets.publishing.service.gov.uk/static/apple-touch-icon-a318f305290c523aed80082456175b46c95350c0eeac93f42e78a71c7a55544e.png" rel="apple-touch-icon"/>
#  <meta content="#0b0c0c" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <!--[if gt IE 8]><!--><link href="https://assets.publishing.service.gov.uk/static/core-layout-1924d57f4bba2603a29dda66a0fb53ded6bc766e697e13c27b52db13ddef3a7b.css" media="screen" rel="stylesheet"/>
#  <!--<![endif]-->
#  <!--[if IE 8]><link rel="stylesheet" media="screen" href="https://assets.publishing.service.gov.uk/static/core-layout-ie8-40c60d07866c397b92055d03e2ba718d212ede58a127f1f61696ab648d8b123d.css" /><script>var ieVersion = 8;</script><![endif]-->
#  <link href="https://assets.publishing.service.gov.uk/static/core-layout-print-e5e1eaa5adefa3987302e6761ce03133d44b120aadb23c61db441df0cf4a852b.css" media="print" rel="stylesheet"/>
#  <script src="https://assets.publishing.service.gov.uk/static/global-bar-init-3abac7067a4f91eb71d1587e3b44c073e372dbe21a187cb6a9e165619667e998.js"></script>
#  <script>
#        if (GOVUK.globalBarInit) {
#          window.GOVUK.globalBarInit.init()
#        }
#      </script>
#  <meta content="https://assets.publishing.service.gov.uk/static/opengraph-image-a1f7d89ffd0782738b1aeb0da37842d8bd0addbd724b8e58c3edbc7287cc11de.png" property="og:image"/>
#  <link href="https://assets.publishing.service.gov.uk/government-frontend/application-c4faf033b8bda5f85672660321358500e2430ae28600bf1b62d2858f93355911.css" media="screen" rel="stylesheet"/>
#  <link href="https://assets.publishing.service.gov.uk/government-frontend/print-75909aa8c79ec8aa897d6e3bd44031259a95acfefd954436144a38f750771ffc.css" media="print" rel="stylesheet"/>
#  <link href="https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019" rel="canonical"/>
#  <meta content="government-frontend" name="govuk:rendering-application"/>
#  </head>
#  <body>
#  <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
#  <div id="skiplink-container">
#  <div>
#  <a class="skiplink govuk-link" href="#content">Skip to main content</a>
#  </div>
#  </div>
#  <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
#  <div class="gem-c-cookie-banner__wrapper govuk-width-container">
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-cookie-banner__message">
#  <span class="govuk-heading-m">Tell us whether you accept cookies</span>
#  <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
#  </div>
#  <div class="gem-c-cookie-banner__buttons">
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
#  </div>
#  <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
#  <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
#  <p class="gem-c-cookie-banner__confirmation-message">
#        You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#      </p>
#  <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
#  </div>
#  </div>
#  <header class="" id="global-header" role="banner">
#  <div class="header-wrapper">
#  <div class="header-global">
#  <div class="header-logo">
#  <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
#  <span class="govuk-header__logotype">
#  <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
#  <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#  </path>
#  <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
#  </svg>
#  <span class="govuk-header__logotype-text">
#                    GOV.UK
#                  </span>
#  </span>
#  </a>
#  </div>
#  <a class="search-toggle js-header-toggle" href="#search">Search</a>
#  <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
#  <div class="content govuk-clearfix">
#  <label for="site-search-text">Search</label>
#  <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
#  <input class="submit" type="submit" value="Search"/>
#  </div>
#  </form>
#  </div>
#  </div>
#  </header>
#  <div id="user-satisfaction-survey-container"></div>
#  <div id="global-header-bar"></div>
#  <!--[if gt IE 7]><!-->
#  <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
#  <div class="global-bar-message-container">
#  <p class="global-bar-message">
#  <span class="global-bar-title">The UK has left the EU</span>
#  <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
#  </p>
#  <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
#  </div>
#  </div>
#  <!--<![endif]-->
#  <div class="direction-ltr" id="wrapper">
#  <div class="gem-c-contextual-breadcrumbs">
#  <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
#  <ol class="govuk-breadcrumbs__list">
#  <li aria-current="false" class="govuk-breadcrumbs__list-item">
#  <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
#  </li>
#  <li aria-current="false" class="govuk-breadcrumbs__list-item">
#  <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="2" data-track-category="breadcrumbClicked" data-track-label="/employment-tribunal-decisions" data-track-options='{"dimension28":"2","dimension29":"Employment tribunal decisions"}' href="/employment-tribunal-decisions">Employment tribunal decisions</a>
#  </li>
#  </ol>
#  </div>
#  </div>
#  <main class="specialist-document" id="content" lang="en" role="main">
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds responsive-top-margin">
#  <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
#  <h1 class="gem-c-title__text gem-c-title__text--long">
#      Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019
#    </h1>
#  </div>
#  </div>
#  <div class="govuk-grid-column-two-thirds">
#  <p class="gem-c-lead-paragraph">Employment Tribunal decision.</p>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="metadata-logo-wrapper">
#  <div class="govuk-grid-column-two-thirds metadata-column">
#  <div class="app-c-publisher-metadata" lang="en">
#  <div class="app-c-published-dates" lang="en">
#      Published 14 February 2020
#  </div>
#  <div class="app-c-publisher-metadata__other">
#  <dl data-module="track-click">
#  <dt class="app-c-publisher-metadata__term">
#                From:
#              </dt>
#  <dd class="app-c-publisher-metadata__definition" data-module="gem-toggle">
#  <span class="app-c-publisher-metadata__definition-sentence">
#  <a class="govuk-link" href="/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a class="govuk-link" href="/courts-tribunals/employment-tribunal">Employment Tribunal</a>
#  </span>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="app-c-important-metadata app-c-important-metadata--bottom-margin">
#  <dl data-module="track-click">
#  <dt class="app-c-important-metadata__term">Decision date: </dt>
#  <dd class="app-c-important-metadata__definition">10 December 2019</dd>
#  <dt class="app-c-important-metadata__term">Country: </dt>
#  <dd class="app-c-important-metadata__definition"><a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_country%5B%5D=england-and-wales">England and Wales</a></dd>
#  <dt class="app-c-important-metadata__term">Jurisdiction code: </dt>
#  <dd class="app-c-important-metadata__definition">
#  <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=health-safety">Health &amp; Safety</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=public-interest-disclosure">Public Interest Disclosure</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=sex-discrimination">Sex Discrimination</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=unfair-dismissal">Unfair Dismissal</a>
#  </dd>
#  </dl>
#  </div>
#  <div class="app-c-contents-list-with-body" id="contents">
#  <div class="responsive-bottom-margin">
#  <div class="gem-c-govspeak govuk-govspeak direction-ltr" data-module="govspeak">
#  <p>Read the full decision in  <span class="attachment-inline" id="attachment_f033a33b-568e-4985-95dd-6caca89c6f07"><a href="https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf">Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal</a></span>.</p>
#  </div>
#  </div>
#  <div class="responsive-bottom-margin">
#  <div class="app-c-published-dates" lang="en">
#      Published 14 February 2020
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  <div class="gem-c-contextual-sidebar">
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-contextual-footer">
#  <div class="gem-c-related-navigation">
#  <nav aria-labelledby="related-nav-topics-a86c4bc7" class="gem-c-related-navigation__nav-section" data-module="gem-toggle" role="navigation">
#  <h2 class="gem-c-related-navigation__sub-heading gem-c-related-navigation__sub-heading--footer" data-track-count="footerRelatedItemSection" id="related-nav-topics-a86c4bc7">Explore the topic</h2>
#  <ul class="gem-c-related-navigation__link-list" data-module="track-click">
#  <li class="gem-c-related-navigation__link"><a class="gem-c-related-navigation__section-link gem-c-related-navigation__section-link--footer" data-track-action="1.1 Explore the topic" data-track-category="relatedLinkClicked" data-track-label="/crime-justice-and-law/courts-sentencing-tribunals" data-track-options='{"dimension28":"1","dimension29":"Courts, sentencing and tribunals"}' href="/crime-justice-and-law/courts-sentencing-tribunals">Courts, sentencing and tribunals</a></li>
#  </ul>
#  </nav>
#  </div>
#  </div>
#  </div>
#  </div>
#  </main>
#  <div class="gem-c-feedback gem-c-feedback--top-margin" data-module="feedback">
#  <div class="gem-c-feedback__prompt gem-c-feedback__js-show js-prompt" tabindex="-1">
#  <div class="gem-c-feedback__js-prompt-questions js-prompt-questions">
#  <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
#  <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#          Maybe
#  </a> <ul class="gem-c-feedback__option-list">
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
#  <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            Yes <span class="visually-hidden">this page is useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
#  <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#            No <span class="visually-hidden">this page is not useful</span>
#  </a> </li>
#  <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
#  <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#            Is there anything wrong with this page?
#  </a> </li>
#  </ul>
#  </div>
#  <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#      Thank you for your feedback
#    </div>
#  </div>
#  <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
#  <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds">
#  <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
#  <input name="url" type="hidden" value="https://www.gov.uk//employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-d3f2a997">
#    What were you doing?
#  </label>
#  <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-d3f2a997" name="what_doing" type="text"/>
#  </div>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-49d5cc8c">
#    What went wrong?
#  </label>
#  <input class="gem-c-input govuk-input" id="input-49d5cc8c" name="what_wrong" type="text"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send</button>
#  </div>
#  </div>
#  </form>
#  <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
#  <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
#  <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
#  <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
#  <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
#  <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
#  <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
#  <div class="govuk-form-group">
#  <label class="gem-c-label govuk-label" for="input-752df6bf">
#    Email address
#  </label>
#  <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-752df6bf" name="email_survey_signup[email_address]" type="email"/>
#  </div>
#  <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  <footer class="group js-footer" id="footer" role="contentinfo">
#  <div class="govuk-width-container">
#  <div class="footer-container govuk-main-wrapper">
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Transition period</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                 Find out what it means for you
#              </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="govuk-grid-row footer-categories" data-module="track-click">
#  <div class="govuk-grid-column-two-thirds">
#  <h2>Services and information</h2>
#  <div class="govuk-grid-row">
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                    Benefits
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                    Births, deaths, marriages and care
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                    Business and self-employed
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                    Childcare and parenting
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                    Citizenship and living in the UK
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                    Crime, justice and the law
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                    Disabled people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                    Driving and transport
#                  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="govuk-grid-column-one-half">
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                    Education and learning
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                    Employing people
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                    Environment and countryside
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                    Housing and local services
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                    Money and tax
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                    Passports, travel and living abroad
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                    Visas and immigration
#                  </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                    Working, jobs and pensions
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="govuk-grid-column-one-third">
#  <h2>Departments and policy</h2>
#  <ul>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#                How government works
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#                Departments
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#                Worldwide
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#                Services
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#                Guidance and regulation
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#                News and communications
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#                Research and statistics
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#                Policy papers and consultations
#              </a>
#  </li>
#  <li>
#  <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#                Transparency and freedom of information releases
#              </a>
#  </li>
#  </ul>
#  </div>
#  <hr/>
#  </div>
#  <div class="footer-meta">
#  <div class="footer-meta-inner">
#  <h2 class="visuallyhidden">Support links</h2>
#  <ul>
#  <li><a class="govuk-link" href="/help">Help</a></li>
#  <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
#  <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
#  <li><a class="govuk-link" href="/contact">Contact</a></li>
#  <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
#  <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
#  <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
#  <li>
#      Built by the
#      <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#        Government Digital Service
#      </a>
#  </li>
#  </ul>
#  <div class="open-government-licence">
#  <p class="logo">
#  <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                      Open Government Licence
#                    </a>
#  </p>
#  <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
#  </div>
#  </div>
#  <div class="copyright">
#  <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                   © Crown copyright
#                </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </footer>
#  <div class="app-error hidden" id="global-app-error"></div>
#  <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
#  <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
#  <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
#  <script src="https://assets.publishing.service.gov.uk/government-frontend/application-6323e1ed84f4f2ae6ee1cd2f5710c1527a5ce122b319d1b0ccb645554d2b1a05.js"></script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"Article","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"},"headline":"Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019","datePublished":"2020-02-14T14:56:29.000+00:00","dateModified":"2020-02-14T14:56:29.000+00:00","description":"Employment Tribunal decision.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"],"author":{"@type":"Organization","name":"HM Courts \u0026 Tribunals Service","url":"https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service"},"about":[{"@context":"http://schema.org","@type":"Thing","sameAs":"https://www.gov.uk/crime-justice-and-law/courts-sentencing-tribunals"}],"articleBody":"\u003cp\u003eRead the full decision in  \u003cspan id=\"attachment_f033a33b-568e-4985-95dd-6caca89c6f07\" class=\"attachment-inline\"\u003e\u003ca href=\"https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf\"\u003eMs A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal\u003c/a\u003e\u003c/span\u003e.\u003c/p\u003e\n"}
#  </script><script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}},{"@type":"ListItem","position":2,"item":{"name":"Employment tribunal decisions","@id":"https://www.gov.uk/employment-tribunal-decisions"}}]}
#  </script>
#  </body>
#  </html>,
#  '\n']

# %%
[type(item) for item in list(casesoup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.Comment,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
casehtml = list(casesoup.children)[4]

# %%
casebody = list(casehtml.children)[5]

# %%
casebody.find_all("dd",class_="app-c-important-metadata__definition")
# Out:
# [<dd class="app-c-important-metadata__definition">10 December 2019</dd>,
#  <dd class="app-c-important-metadata__definition"><a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_country%5B%5D=england-and-wales">England and Wales</a></dd>,
#  <dd class="app-c-important-metadata__definition">
#  <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=health-safety">Health &amp; Safety</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=public-interest-disclosure">Public Interest Disclosure</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=sex-discrimination">Sex Discrimination</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=unfair-dismissal">Unfair Dismissal</a>
#  </dd>]

# %%
# Yet another way to get the date
casebody.find_all("dd",class_="app-c-important-metadata__definition")[0].get_text()
# Out:
# '10 December 2019'

# %%
# And here's the country
casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()
# Out:
# 'England and Wales'

# %%
# Another ctr+f search for 'withdrawal' gives us the outcome. 
casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]
# Out:
# 'Withdrawal'

# %%
# And the same div also contains the case number. 
casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()
# Out:
# '\nRead the full decision in  Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal.\n'

# %%
# casenumber
casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/')[0].split(': ')[1]
# Out:
# '2302421'

# %% [markdown]
# ## Let's start tidying this up into a dataframe

# %%
import pandas as pd

# %%
case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/')[0].split(': ')[1]], 
         'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
         'Date': [case.find("time")['datetime']], 
         'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]]}

# %%
case_df = pd.DataFrame.from_dict(case0)

# %%
case_df
# Out:
#     CaseNr            Country        Date     Outcome
# 0  2302421  England and Wales  2019-12-10  Withdrawal

# %% [markdown]
# Search for jurisdiction

# %%
casebody
# Out:
# <body>
# <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
# <div id="skiplink-container">
# <div>
# <a class="skiplink govuk-link" href="#content">Skip to main content</a>
# </div>
# </div>
# <div aria-label="cookie banner" class="gem-c-cookie-banner govuk-clearfix" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
# <div class="gem-c-cookie-banner__wrapper govuk-width-container">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-cookie-banner__message">
# <span class="govuk-heading-m">Tell us whether you accept cookies</span>
# <p class="govuk-body">We use <a class="govuk-link" href="/help/cookies">cookies to collect information</a> about how you use GOV.UK. We use this information to make the website work as well as possible and improve government services.</p>
# </div>
# <div class="gem-c-cookie-banner__buttons">
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-accept govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <button class="gem-c-button govuk-button gem-c-button--inline" data-accept-cookies="true" data-module="track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept all cookies</button>
# </div>
# <div class="gem-c-cookie-banner__button gem-c-cookie-banner__button-settings govuk-grid-column-full govuk-grid-column-one-half-from-desktop">
# <a class="gem-c-button govuk-button gem-c-button--inline" data-module="track-click" data-track-action="Cookie banner settings clicked" data-track-category="cookieBanner" href="/help/cookies" role="button">Set cookie preferences</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="gem-c-cookie-banner__confirmation govuk-width-container" tabindex="-1">
# <p class="gem-c-cookie-banner__confirmation-message">
#       You’ve accepted all cookies. You can <a class="govuk-link" data-module="track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.
#     </p>
# <button class="gem-c-cookie-banner__hide-button" data-hide-cookie-banner="true" data-module="track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">Hide</button>
# </div>
# </div>
# <header class="" id="global-header" role="banner">
# <div class="header-wrapper">
# <div class="header-global">
# <div class="header-logo">
# <a class="content govuk-header__link govuk-header__link--homepage" data-module="track-click" data-track-action="homeHeader" data-track-category="homeLinkClicked" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
# <span class="govuk-header__logotype">
# <svg class="govuk-header__logotype-crown" focusable="false" height="30" role="presentation" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
# </path>
# <image class="govuk-header__logotype-crown-fallback-image" height="32" src="https://assets.publishing.service.gov.uk/static/gov.uk_logotype_crown_invert_trans-203e1db49d3eff430d7dc450ce723c1002542fe1d2bce661b6d8571f14c1043c.png" width="36" xlink:href=""/>
# </svg>
# <span class="govuk-header__logotype-text">
#                   GOV.UK
#                 </span>
# </span>
# </a>
# </div>
# <a class="search-toggle js-header-toggle" href="#search">Search</a>
# <form action="/search" class="site-search govuk-clearfix" id="search" method="get" role="search">
# <div class="content govuk-clearfix">
# <label for="site-search-text">Search</label>
# <input class="js-search-focus" id="site-search-text" name="q" title="Search" type="search"/>
# <input class="submit" type="submit" value="Search"/>
# </div>
# </form>
# </div>
# </div>
# </header>
# <div id="user-satisfaction-survey-container"></div>
# <div id="global-header-bar"></div>
# <!--[if gt IE 7]><!-->
# <div class="global-bar dont-print" data-module="global-bar" id="global-bar">
# <div class="global-bar-message-container">
# <p class="global-bar-message">
# <span class="global-bar-title">The UK has left the EU</span>
# <a class="govuk-link js-call-to-action" href="/transition" rel="external noreferrer">Find out what this means for you</a>
# </p>
# <a aria-controls="global-bar" class="govuk-link dismiss" href="#hide-message" role="button">Hide message</a>
# </div>
# </div>
# <!--<![endif]-->
# <div class="direction-ltr" id="wrapper">
# <div class="gem-c-contextual-breadcrumbs">
# <div class="gem-c-breadcrumbs govuk-breadcrumbs" data-module="track-click">
# <ol class="govuk-breadcrumbs__list">
# <li aria-current="false" class="govuk-breadcrumbs__list-item">
# <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
# </li>
# <li aria-current="false" class="govuk-breadcrumbs__list-item">
# <a aria-current="false" class="govuk-breadcrumbs__link" data-track-action="2" data-track-category="breadcrumbClicked" data-track-label="/employment-tribunal-decisions" data-track-options='{"dimension28":"2","dimension29":"Employment tribunal decisions"}' href="/employment-tribunal-decisions">Employment tribunal decisions</a>
# </li>
# </ol>
# </div>
# </div>
# <main class="specialist-document" id="content" lang="en" role="main">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds responsive-top-margin">
# <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
# <h1 class="gem-c-title__text gem-c-title__text--long">
#     Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019
#   </h1>
# </div>
# </div>
# <div class="govuk-grid-column-two-thirds">
# <p class="gem-c-lead-paragraph">Employment Tribunal decision.</p>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="metadata-logo-wrapper">
# <div class="govuk-grid-column-two-thirds metadata-column">
# <div class="app-c-publisher-metadata" lang="en">
# <div class="app-c-published-dates" lang="en">
#     Published 14 February 2020
# </div>
# <div class="app-c-publisher-metadata__other">
# <dl data-module="track-click">
# <dt class="app-c-publisher-metadata__term">
#               From:
#             </dt>
# <dd class="app-c-publisher-metadata__definition" data-module="gem-toggle">
# <span class="app-c-publisher-metadata__definition-sentence">
# <a class="govuk-link" href="/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a class="govuk-link" href="/courts-tribunals/employment-tribunal">Employment Tribunal</a>
# </span>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# </div>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="app-c-important-metadata app-c-important-metadata--bottom-margin">
# <dl data-module="track-click">
# <dt class="app-c-important-metadata__term">Decision date: </dt>
# <dd class="app-c-important-metadata__definition">10 December 2019</dd>
# <dt class="app-c-important-metadata__term">Country: </dt>
# <dd class="app-c-important-metadata__definition"><a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_country%5B%5D=england-and-wales">England and Wales</a></dd>
# <dt class="app-c-important-metadata__term">Jurisdiction code: </dt>
# <dd class="app-c-important-metadata__definition">
# <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=health-safety">Health &amp; Safety</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=public-interest-disclosure">Public Interest Disclosure</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=sex-discrimination">Sex Discrimination</a>, <a class="govuk-link app-link" href="/employment-tribunal-decisions?tribunal_decision_categories%5B%5D=unfair-dismissal">Unfair Dismissal</a>
# </dd>
# </dl>
# </div>
# <div class="app-c-contents-list-with-body" id="contents">
# <div class="responsive-bottom-margin">
# <div class="gem-c-govspeak govuk-govspeak direction-ltr" data-module="govspeak">
# <p>Read the full decision in  <span class="attachment-inline" id="attachment_f033a33b-568e-4985-95dd-6caca89c6f07"><a href="https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf">Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal</a></span>.</p>
# </div>
# </div>
# <div class="responsive-bottom-margin">
# <div class="app-c-published-dates" lang="en">
#     Published 14 February 2020
# </div>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# <div class="gem-c-contextual-sidebar">
# </div>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-contextual-footer">
# <div class="gem-c-related-navigation">
# <nav aria-labelledby="related-nav-topics-a86c4bc7" class="gem-c-related-navigation__nav-section" data-module="gem-toggle" role="navigation">
# <h2 class="gem-c-related-navigation__sub-heading gem-c-related-navigation__sub-heading--footer" data-track-count="footerRelatedItemSection" id="related-nav-topics-a86c4bc7">Explore the topic</h2>
# <ul class="gem-c-related-navigation__link-list" data-module="track-click">
# <li class="gem-c-related-navigation__link"><a class="gem-c-related-navigation__section-link gem-c-related-navigation__section-link--footer" data-track-action="1.1 Explore the topic" data-track-category="relatedLinkClicked" data-track-label="/crime-justice-and-law/courts-sentencing-tribunals" data-track-options='{"dimension28":"1","dimension29":"Courts, sentencing and tribunals"}' href="/crime-justice-and-law/courts-sentencing-tribunals">Courts, sentencing and tribunals</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="gem-c-feedback gem-c-feedback--top-margin" data-module="feedback">
# <div class="gem-c-feedback__prompt gem-c-feedback__js-show js-prompt" tabindex="-1">
# <div class="gem-c-feedback__js-prompt-questions js-prompt-questions">
# <h2 class="gem-c-feedback__prompt-question">Is this page useful?</h2>
# <a aria-expanded="false" aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button" style="display: none;">
#         Maybe
# </a> <ul class="gem-c-feedback__option-list">
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--useful">
# <a aria-expanded="false" class="gem-c-feedback__prompt-link js-page-is-useful" data-track-action="ffYesClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           Yes <span class="visually-hidden">this page is useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--not-useful">
# <a aria-controls="page-is-not-useful" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-page-is-not-useful" data-track-action="ffNoClick" data-track-category="yesNoFeedbackForm" href="/contact/govuk" role="button">
#           No <span class="visually-hidden">this page is not useful</span>
# </a> </li>
# <li class="gem-c-feedback__option-list-item gem-c-feedback__option-list-item--wrong">
# <a aria-controls="something-is-wrong" aria-expanded="false" class="gem-c-feedback__prompt-link js-toggle-form js-something-is-wrong" data-track-action="GOV.UK Open Form" data-track-category="Onsite Feedback" href="/contact/govuk" role="button">
#           Is there anything wrong with this page?
# </a> </li>
# </ul>
# </div>
# <div class="gem-c-feedback__prompt-success js-prompt-success js-hidden" tabindex="-1">
#     Thank you for your feedback
#   </div>
# </div>
# <form action="/contact/govuk/problem_reports" class="gem-c-feedback__form js-feedback-form js-hidden" data-track-action="GOV.UK Send Form" data-track-category="Onsite Feedback" id="something-is-wrong" method="post">
# <a aria-controls="something-is-wrong" aria-expanded="true" class="gem-c-feedback__close gem-c-feedback__js-show js-close-form" data-track-action="GOV.UK Close Form" data-track-category="Onsite Feedback" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-feedback__error-summary gem-c-feedback__js-show js-hidden js-errors" tabindex="-1"></div>
# <input name="url" type="hidden" value="https://www.gov.uk//employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="feedback_explanation">Don’t include personal or financial information like your National Insurance number or credit card details.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-d3f2a997">
#   What were you doing?
# </label>
# <input aria-describedby="feedback_explanation" class="gem-c-input govuk-input" id="input-d3f2a997" name="what_doing" type="text"/>
# </div>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-49d5cc8c">
#   What went wrong?
# </label>
# <input class="gem-c-input govuk-input" id="input-49d5cc8c" name="what_wrong" type="text"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send</button>
# </div>
# </div>
# </form>
# <form action="/contact/govuk/email-survey-signup" class="gem-c-feedback__form gem-c-feedback__form--email gem-c-feedback__js-show js-feedback-form js-hidden" data-track-action="Send Form" data-track-category="yesNoFeedbackForm" id="page-is-not-useful" method="post">
# <a aria-controls="page-is-not-useful" aria-expanded="true" class="gem-c-feedback__close js-close-form" data-track-action="ffFormClose" data-track-category="yesNoFeedbackForm" href="#" role="button">Close</a>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds" id="survey-wrapper">
# <div class="gem-c-feedback__error-summary js-hidden js-errors" tabindex="-1"></div>
# <input name="email_survey_signup[survey_id]" type="hidden" value="footer_satisfaction_survey"/>
# <input name="email_survey_signup[survey_source]" type="hidden" value="/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"/>
# <h3 class="gem-c-feedback__form-heading">Help us improve GOV.UK</h3>
# <p class="gem-c-feedback__form-paragraph" id="survey_explanation">To help us improve GOV.UK, we’d like to know more about your visit today. We’ll send you a link to a feedback form. It will take only 2 minutes to fill in. Don’t worry we won’t send you spam or share your email address with anyone.</p>
# <div class="govuk-form-group">
# <label class="gem-c-label govuk-label" for="input-752df6bf">
#   Email address
# </label>
# <input aria-describedby="survey_explanation" autocomplete="email" class="gem-c-input govuk-input" id="input-752df6bf" name="email_survey_signup[email_address]" type="email"/>
# </div>
# <button class="gem-c-button govuk-button" type="submit">Send me the survey</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <footer class="group js-footer" id="footer" role="contentinfo">
# <div class="govuk-width-container">
# <div class="footer-container govuk-main-wrapper">
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Transition period</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="transitionLinks" data-track-category="footerClicked" data-track-label="Find out what it means for you" href="/transition">
#                Find out what it means for you
#             </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="govuk-grid-row footer-categories" data-module="track-click">
# <div class="govuk-grid-column-two-thirds">
# <h2>Services and information</h2>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Benefits" href="/browse/benefits">
#                   Benefits
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Births, deaths, marriages and care" href="/browse/births-deaths-marriages">
#                   Births, deaths, marriages and care
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Business and self-employed" href="/browse/business">
#                   Business and self-employed
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="" href="/browse/childcare-parenting">
#                   Childcare and parenting
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Citizenship and living in the UK" href="/browse/citizenship">
#                   Citizenship and living in the UK
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Crime, justice and the law" href="/browse/justice">
#                   Crime, justice and the law
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Disabled people" href="/browse/disabilities">
#                   Disabled people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Driving and transport" href="/browse/driving">
#                   Driving and transport
#                 </a>
# </li>
# </ul>
# </div>
# <div class="govuk-grid-column-one-half">
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Education and learning" href="/browse/education">
#                   Education and learning
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Employing people" href="/browse/employing-people">
#                   Employing people
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Environment and countryside" href="/browse/environment-countryside">
#                   Environment and countryside
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Housing and local services" href="/browse/housing-local-services">
#                   Housing and local services
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Money and tax" href="/browse/tax">
#                   Money and tax
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Passports, travel and living abroad" href="/browse/abroad">
#                   Passports, travel and living abroad
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Visas and immigration" href="/browse/visas-immigration">
#                   Visas and immigration
#                 </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Working, jobs and pensions" href="/browse/working">
#                   Working, jobs and pensions
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="govuk-grid-column-one-third">
# <h2>Departments and policy</h2>
# <ul>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="How government works" href="/government/how-government-works">
#               How government works
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Departments" href="/government/organisations">
#               Departments
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Worldwide" href="/world">
#               Worldwide
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Services" href="/search/services">
#               Services
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Guidance and regulation" href="/search/guidance-and-regulation">
#               Guidance and regulation
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="News and communications" href="/search/news-and-communications">
#               News and communications
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Research and statistics" href="/search/research-and-statistics">
#               Research and statistics
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Policy papers and consultations" href="/search/policy-papers-and-consultations">
#               Policy papers and consultations
#             </a>
# </li>
# <li>
# <a class="govuk-link" data-track-action="footerLinks" data-track-category="footerClicked" data-track-label="Transparency and freedom of information releases" href="/search/transparency-and-freedom-of-information-releases">
#               Transparency and freedom of information releases
#             </a>
# </li>
# </ul>
# </div>
# <hr/>
# </div>
# <div class="footer-meta">
# <div class="footer-meta-inner">
# <h2 class="visuallyhidden">Support links</h2>
# <ul>
# <li><a class="govuk-link" href="/help">Help</a></li>
# <li><a class="govuk-link" href="/help/privacy-notice">Privacy</a></li>
# <li><a class="govuk-link" href="/help/cookies">Cookies</a></li>
# <li><a class="govuk-link" href="/contact">Contact</a></li>
# <li><a class="govuk-link" href="/help/accessibility-statement">Accessibility statement</a></li>
# <li><a class="govuk-link" href="/help/terms-conditions">Terms and conditions</a></li>
# <li><a class="govuk-link" href="/cymraeg" hreflang="cy" lang="cy">Rhestr o Wasanaethau Cymraeg</a></li>
# <li>
#     Built by the
#     <a class="govuk-link" href="https://www.gov.uk/government/organisations/government-digital-service">
#       Government Digital Service
#     </a>
# </li>
# </ul>
# <div class="open-government-licence">
# <p class="logo">
# <a class="govuk-link open-government-licence__logo-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">
#                     Open Government Licence
#                   </a>
# </p>
# <p>All content is available under the <a class="govuk-link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated</p>
# </div>
# </div>
# <div class="copyright">
# <a class="govuk-link" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">
#                  © Crown copyright
#               </a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="app-error hidden" id="global-app-error"></div>
# <script src="https://assets.publishing.service.gov.uk/static/libs/jquery/jquery-1.12.4-c731c20e2995c576b0509d3bd776f7ab64a66b95363a3b5fae9864299ee594ed.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/header-footer-only-e51dd28b34cb78151891e0553a8eaabd9ea0bc039e33123d71f6d7c32f5dc7a9.js"></script>
# <script src="https://assets.publishing.service.gov.uk/static/surveys-f0adf267a87ca20a7abf05f7e6c9ed1a349295efb5d59269bc06172eea23d1b0.js"></script>
# <script>if (typeof window.GOVUK === 'undefined') document.body.className = document.body.className.replace('js-enabled', '');</script>
# <script src="https://assets.publishing.service.gov.uk/government-frontend/application-6323e1ed84f4f2ae6ee1cd2f5710c1527a5ce122b319d1b0ccb645554d2b1a05.js"></script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"Article","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.gov.uk/employment-tribunal-decisions/ms-a-mullally-v-virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019"},"headline":"Ms A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019","datePublished":"2020-02-14T14:56:29.000+00:00","dateModified":"2020-02-14T14:56:29.000+00:00","description":"Employment Tribunal decision.","publisher":{"@type":"Organization","name":"GOV.UK","url":"https://www.gov.uk","logo":{"@type":"ImageObject","url":"https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-logo-e5962881254c9adb48f94d2f627d3bb67f258a6cbccc969e80abb7bbe4622976.png"}},"image":["https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-5ceffac04f7f6d4f421bd1d36dbb723ef48c15426d7f77f90be80a83af3c747e.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-fcfe16abb1a015848e50d2ea797666a9eaf5158dca38ddfb1e52dc8c0543ab74.png","https://assets.publishing.service.gov.uk/government-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-fcf616879a7b37970df4d2117de962e08f7d057674ef1af6063dcdd529424eee.png"],"author":{"@type":"Organization","name":"HM Courts \u0026 Tribunals Service","url":"https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service"},"about":[{"@context":"http://schema.org","@type":"Thing","sameAs":"https://www.gov.uk/crime-justice-and-law/courts-sentencing-tribunals"}],"articleBody":"\u003cp\u003eRead the full decision in  \u003cspan id=\"attachment_f033a33b-568e-4985-95dd-6caca89c6f07\" class=\"attachment-inline\"\u003e\u003ca href=\"https://assets.publishing.service.gov.uk/media/5e44206b40f0b677c6c66fc8/Ms_A_Mullally_v_1__Virgin_Atlantic_Airways_Limited_2__Mr_Shaun_Laverty_2302421-2019_Preliminary_10.12.2019_.pdf\"\u003eMs A Mullally v Virgin Atlantic Airways Ltd and Mr Shaun Laverty: 2302421/2019 - Withdrawal\u003c/a\u003e\u003c/span\u003e.\u003c/p\u003e\n"}
# </script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Home","@id":"https://www.gov.uk/"}},{"@type":"ListItem","position":2,"item":{"name":"Employment tribunal decisions","@id":"https://www.gov.uk/employment-tribunal-decisions"}}]}
# </script>
# </body>

# %%
casebody.find_all('dd', class_='app-c-important-metadata__definition')[2].get_text()[1:-1]
# Out:
# 'Health & Safety, Public Interest Disclosure, Sex Discrimination, Unfair Dismissal'

# %% [markdown]
# Slightly messy and seems to have several codes, but found.

# %% [markdown]
# Finally, claimant and defendant, which is actually in the URL

# %%
case.find("a")['href'].split('/')[-1].split('-v-')
# Out:
# ['ms-a-mullally',
#  'virgin-atlantic-airways-ltd-and-mr-shaun-laverty-2302421-2019']

# %%
claimant = case.find("a")['href'].split('/')[-1].split('-v-')[0]

# %%
claimant
# Out:
# 'ms-a-mullally'

# %%
import re
defendent = case.find("a")['href'].split('/')[-1].split('-v-')[1].split(str(int(re.search(r'\d+', case.find("a")['href'].split('/')[-1].split('-v-')[1]).group())))[0]

# %%
defendent
# Out:
# 'virgin-atlantic-airways-ltd-and-mr-shaun-laverty-'

# %% [markdown]
# ## Let's add these to our dataframe

# %%
case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/')[0].split(': ')[1]], 
         'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
         'Date': [case.find("time")['datetime']], 
         'Jurisdiction' : [casebody.find_all('dd', class_='app-c-important-metadata__definition')[2].get_text()[1:-1]],
         'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
         'Claimant' : [case.find("a")['href'].split('/')[-1].split('-v-')[0]],
         'Defendent' : [case.find("a")['href'].split('/')[-1].split('-v-')[1].split(str(int(re.search(r'\d+', case.find("a")['href'].split('/')[-1].split('-v-')[1]).group())))[0]]}

# %%
case_df = pd.DataFrame.from_dict(case0)

# %%
case_df
# Out:
#     CaseNr            Country        Date  \
# 0  2302421  England and Wales  2019-12-10
#
#                                         Jurisdiction     Outcome  \
# 0  Health & Safety, Public Interest Disclosure, S...  Withdrawal
#
#         Claimant                                          Defendent
# 0  ms-a-mullally  virgin-atlantic-airways-ltd-and-mr-shaun-laverty-

# %% [markdown]
# ## That looks great. Let's tidy everything up and call it a day

# %%
import re
import pandas as pd

# %%
page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page=1")
soup = BeautifulSoup(page.content, 'html.parser')

cases = list(soup.find_all("li", class_="gem-c-document-list__item"))
case = cases[0]
casepage = requests.get("https://www.gov.uk/"+case.find("a")['href'])
casesoup = BeautifulSoup(casepage.content, 'html.parser')
casehtml = list(casesoup.children)[4]
casebody = list(casehtml.children)[5]

case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1]], 
         'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
         'Date': [case.find("time")['datetime']], 
         'Jurisdiction' : [casebody.find_all('dd', class_='app-c-important-metadata__definition')[2].get_text()[1:-1]],
         'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
         'Claimant' : [case.find("a")['href'].split('/')[-1].split('-v-')[0]],
         'Defendent' : [case.find("a")['href'].split('/')[-1].split('-v-')[1].split(str(int(re.search(r'\d+', case.find("a")['href'].split('/')[-1].split('-v-')[1]).group())))[0]]}
case_df = case_df.append(pd.DataFrame.from_dict(case0))

# %%
columns = case_df.columns

# %% [markdown]
# Next steps:
# - Ms K Game v Unique Associates Ltd T/a Threshold Surveyors: 3325880/2017 is an anomaly. Have a closer look
# - loop over case in cases
# - loop for pagenumber in range...
# - Find where legal representation sits

# %% [markdown]
# the / in casenumber wasn't specific enough. Changed to /20 assuming all cases are from this millenium

# %%
page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page=1")
soup = BeautifulSoup(page.content, 'html.parser')
case_df = pd.DataFrame(columns = columns)
cases = list(soup.find_all("li", class_="gem-c-document-list__item"))

for case in cases:
    casepage = requests.get("https://www.gov.uk/"+case.find("a")['href'])
    casesoup = BeautifulSoup(casepage.content, 'html.parser')
    casehtml = list(casesoup.children)[4]
    casebody = list(casehtml.children)[5]

    case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1]], 
             'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
             'Date': [case.find("time")['datetime']], 
             'Jurisdiction' : [find_jurisdiction(casebody)],
             'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
             'Claimant' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[0]],
             'Defendent' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[1].split(': ')[0]]}
    case_df = case_df.append(pd.DataFrame.from_dict(case0))

# %%
case_df
# Out:
#     CaseNr            Country        Date  \
# 0  1601153  England and Wales  2018-06-19
# 0  2302421  England and Wales  2019-12-10
# 0  2303643  England and Wales  2020-01-09
# 0  2301192  England and Wales  2020-01-06
# 0  2303800  England and Wales  2019-12-19
# 0  2303040  England and Wales  2019-12-19
# 0  2300468  England and Wales  2020-01-08
# 0  3325880  England and Wales  2020-01-09
# 0  2302522  England and Wales  2019-12-19
# 0  2302201  England and Wales  2019-12-09
# 0  2300984  England and Wales  2019-12-19
# 0  2301255  England and Wales  2019-12-20
# 0  4113485           Scotland  2019-12-10
# 0  4111315           Scotland  2019-12-10
# 0  4113773           Scotland  2019-12-12
# 0  4111312           Scotland  2019-12-09
# 0  2302291  England and Wales  2020-01-09
# 0  4112158           Scotland  2019-12-06
# 0  4111777           Scotland  2019-12-02
# 0  4110801           Scotland  2019-12-02
# 0  4112076           Scotland  2019-12-03
# 0  2302061  England and Wales  2019-12-17
# 0  4106906           Scotland  2019-12-19
# 0  4107805           Scotland  2019-12-16
# 0  4106020           Scotland  2019-12-13
# 0  4106442           Scotland  2019-12-09
# 0  2302329  England and Wales  2019-10-31
# 0  4102897           Scotland  2019-12-09
# 0  4107798           Scotland  2019-12-09
# 0  4109351           Scotland  2019-12-05
# 0  4106826           Scotland  2019-12-02
# 0  4107509           Scotland  2019-12-02
# 0  4108624           Scotland  2019-12-04
# 0  4107543           Scotland  2019-11-28
# 0  4105000           Scotland  2020-02-11
# 0  2302605  England and Wales  2019-12-19
# 0  2304669  England and Wales  2019-12-31
# 0  2304160  England and Wales  2019-12-17
# 0  2302249  England and Wales  2019-12-09
# 0  2302325  England and Wales  2019-12-09
# 0  2301976  England and Wales  2020-01-06
# 0  2300142  England and Wales  2019-12-19
# 0  2304566  England and Wales  2019-12-19
# 0  2300659  England and Wales  2019-12-16
# 0  2302085  England and Wales  2019-12-19
# 0  2304141  England and Wales  2019-12-09
# 0  2301286  England and Wales  2019-12-09
# 0  1600473  England and Wales  2020-01-28
# 0  2414718  England and Wales  2020-01-27
# 0  2413228  England and Wales  2020-01-27
#
#                                         Jurisdiction                Outcome  \
# 0           \nSex Discrimination, Unfair Dismissal\n                  Final
# 0  \nHealth & Safety, Public Interest Disclosure,...             Withdrawal
# 0                          Disability Discrimination             Withdrawal
# 0  \nPublic Interest Disclosure, Sex Discriminati...             Withdrawal
# 0  \nBreach of Contract, Unlawful Deduction from ...             Withdrawal
# 0                                 Sex Discrimination             Withdrawal
# 0    \nDisability Discrimination, Unfair Dismissal\n             Withdrawal
# 0  \nBreach of Contract, Contract of Employment, ...               Judgment
# 0  \nBreach of Contract, Unfair Dismissal, Unlawf...             Withdrawal
# 0  \nDisability Discrimination, Public Interest D...             Withdrawal
# 0           \nBreach of Contract, Unfair Dismissal\n             Withdrawal
# 0  \nDisability Discrimination, Unlawful Deductio...     Reserved Judgment
# 0                           Working Time Regulations            Withdrawal
# 0                           Working Time Regulations            Withdrawal
# 0           \nBreach of Contract, Unfair Dismissal\n             Withdrawal
# 0  \nBreach of Contract, Race Discrimination, Rel...             Withdrawal
# 0  \nBreach of Contract, Disability Discrimination\n             Withdrawal
# 0                                     Interim Relief             Withdrawal
# 0                      Unlawful Deduction from Wages             Withdrawal
# 0    \nDisability Discrimination, Unfair Dismissal\n            Withdrawal
# 0  \nBreach of Contract, Disability Discriminatio...             Withdrawal
# 0                                   Unfair Dismissal             Withdrawal
# 0                          Disability Discrimination             Withdrawal
# 0  \nDisability Discrimination, Unlawful Deductio...             Withdrawal
# 0                          Disability Discrimination            Withdrawal
# 0  \nBreach of Contract, Redundancy, Unfair Dismi...             Withdrawal
# 0  \nDisability Discrimination, Race Discriminati...               Judgment
# 0  \nBreach of Contract, Public Interest Disclosu...            Withdrawal
# 0           \nBreach of Contract, Unfair Dismissal\n            Withdrawal
# 0                                   Unfair Dismissal             Withdrawal
# 0    \nDisability Discrimination, Unfair Dismissal\n             Withdrawal
# 0    \nDisability Discrimination, Unfair Dismissal\n             Withdrawal
# 0                                   Unfair Dismissal            Withdrawal
# 0                                    Health & Safety             Withdrawal
# 0  \nRace Discrimination, Unfair Dismissal, Unlaw...  Judgment with Reasons
# 0  \nPublic Interest Disclosure, Race Discriminat...             Withdrawal
# 0                   \nRedundancy, Unfair Dismissal\n             Withdrawal
# 0  \nBreach of Contract, Redundancy, Unfair Dismi...             Withdrawal
# 0           \nAge Discrimination, Unfair Dismissal\n             Withdrawal
# 0  \nContract of Employment, Unfair Dismissal, Un...             Withdrawal
# 0                          Disability Discrimination             Withdrawal
# 0  \nBreach of Contract, Disability Discriminatio...             Withdrawal
# 0  \nBreach of Contract, Unfair Dismissal, Unlawf...             Withdrawal
# 0                          Disability Discrimination        Reconsideration
# 0              \nHealth & Safety, Unfair Dismissal\n             Withdrawal
# 0                          Disability Discrimination                Rule 21
# 0   \nPublic Interest Disclosure, Unfair Dismissal\n             Withdrawal
# 0  \nAge Discrimination, Disability Discriminatio...                  Final
# 0                      Unlawful Deduction from Wages               Judgment
# 0                     Maternity and Pregnancy Rights               Judgment
#
#                  Claimant                                          Defendent
# 0             Miss N Wood                                   Nicola Rebustini
    if text[0:2] == '/n':
        text = text[2:]
    if text[-2:-1] == '/':
        text = text[:-1]
    return text

# %%
# Out:
# 'Working Time Regulations'

# %%
case_df = pd.DataFrame(columns = columns)
cases = list(soup.find_all("li", class_="gem-c-document-list__item"))

case = cases[0]
casepage = requests.get("https://www.gov.uk/"+case.find("a")['href'])
casesoup = BeautifulSoup(casepage.content, 'html.parser')
casehtml = list(casesoup.children)[4]
casebody = list(casehtml.children)[5]

case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1]], 
         'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
         'Date': [case.find("time")['datetime']], 
         'Jurisdiction' : [find_jurisdiction(casebody)],
         'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
         'Claimant' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[0]],
         'Defendent' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[1].split(': ')[0]]}
case_df = case_df.append(pd.DataFrame.from_dict(case0))

# %%
case_df
# Out:
#     CaseNr            Country        Date  \
# 0  1601153  England and Wales  2018-06-19
#
#                            Jurisdiction Outcome     Claimant         Defendent
# 0  Sex Discrimination, Unfair Dismissal   Final  Miss N Wood  Nicola Rebustini

# %%
def find_jurisdiction(casebody):
    text = casebody.find_all('dd', class_='app-c-important-metadata__definition')[2].get_text()
    if text[0:1] == '\n':
        text = text[1:]
    if text[-1] == '\n':
        text = text[:-1]
    return text

# %%
# Out:
# '\nSex Discrimination, Unfair Dismissal'

# %%
# Out:
# 'Sex Discrimination, Unfair Dismissal'

# %% [markdown]
# ## Tidying up time

# %%
def find_jurisdiction(casebody):
    text = casebody.find_all('dd', class_='app-c-important-metadata__definition')[2].get_text()
    if text[0:1] == '\n':
        text = text[1:]
    if text[-1] == '\n':
        text = text[:-1]
    return text

# %%
page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page=1")
soup = BeautifulSoup(page.content, 'html.parser')
case_df = pd.DataFrame(columns = columns)
cases = list(soup.find_all("li", class_="gem-c-document-list__item"))

# %%
case_df = pd.DataFrame(columns = columns)

for i in range(10,1095):
    print("page ", i)
    page = requests.get("https://www.gov.uk/employment-tribunal-decisions?page="+str(i))
    soup = BeautifulSoup(page.content, 'html.parser')
    cases = list(soup.find_all("li", class_="gem-c-document-list__item"))

    for case in cases:
        casepage = requests.get("https://www.gov.uk/"+case.find("a")['href'])
        casesoup = BeautifulSoup(casepage.content, 'html.parser')
        casehtml = list(casesoup.children)[4]
        casebody = list(casehtml.children)[5]
        
        try:
            case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1]], 
                     'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
                     'Date': [case.find("time")['datetime']], 
                     'Jurisdiction' : [find_jurisdiction(casebody)],
                     'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
                     'Claimant' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[0]],
                     'Defendent' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[1].split(': ')[0]]}
            print(casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[0])
            case_df = case_df.append(pd.DataFrame.from_dict(case0))
        except:
            print("error on case: ",casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_
# Read the full decision in Mr D Bennett v Mitie Total Security Ltd 1402055.18.
#
# error on case:
# Read the full decision in Mr C Ratcliff v Babcock HR Department: 1400875/2019.
#
#  Mr M Hayden
# error on case:
# Read the full decision in Mr M Uddin v Eli Lilly and Company Ltd: 1400978/2019.
#
# error on case:
# Read the full decision in Mr A Seidman v Pabellón Ltd: 1405551/2019.
#
# error on case:
# Read the full decision in Mrs G Jones and Mrs S Hunt v Nestor Primecare Services Limited In Administration and Others: 14024744/2019.
#
# error on case:
# Read the full decision in Mrs D James v Dorset Healthcare University NHS Foundation Trust: 1400527/2019.
#
# error on case:
# Read the full decision in Mrs C Ross v Mr Aubrey Wood Ta The Royal Oak WUE: 1400575/2019.
#
# error on case:
# Read the full decision in Mrs P Lock v Anchor Hanover Group: 1403391/2019.
#
# error on case:
# Read the full decision in Mr C Thain v Devon and Somerset Fire and Rescue Authority 1401677.2017.
# Read the full decision in Mr C Thain v Devon and Somerset Fire and Rescue Authority 1401677.2017.
#
# Mrs L Flanders
#  Ms H Kaur
# Ms Z Khan
# Ms K Kot
# Mrs V Tahany
#  Mrs T Meyer
# Mrs L Simpson
# Mrs K Pryor
# Mr R McGlinchey
#  Mr R McCluskey
# Mr P Thiara
# Mr J Power
# Mr J Hulley
# Mr J Digpal
# Mr G Finlay
# Mr G Evans
# Mr C Senior
# Mr A Wood
# Mr A Clark
# Miss N Dickenson
# Miss M Robinson
# Miss J Melbourne
# Miss E Parkin
# Ms S Kaur
#  Ms K B Shah
# Ms B March
# Mrs T White
# Mrs A Parker
# Mr P Huskisson
# Mr M Battistini
# Mr L Smith
# Mr L Harris
# Mr Hamesh Raja
# Mr D Collins
# page  16
# Miss A Latif
#   Mr JM Burdess
# Mr Raymond Levy
#   Mr V Chumber
# Mrs C Smith
#   Miss O Ball
#   Miss M K Rosthorn-Eccles
# Miss S Young
#   Mr Paul Newton
# Miss S Strachan
# Mr M Hogan
#   Paula Clark
#   Mr C Watson
#   Mr A Stock
#   Miss L Fell and others
#   Miss S Whitaker
#   Mrs S Gibson
# Miss P Melia
#   Mrs J Kirkland
#   Ms O Lekka
#   Mr K Bonsu
# Miss J Rowley
#   Mr A James
#   Mr A Hinsley
#   Ms L Reynolds
# Mrs C Hogan
#   Mr D Bell
# Mrs N Bravender
#   Mr K Dainys
#  Miss M S Jain
# Mrs L Edge
# Mr J Spires
# Mr Sikdar
# Mr S Knight
# Mrs E Grady
# Miss M I Benfata
# Mr B Wytrzyszczewski
# Ms Z Peveller
# Ms T Howard
# Ms P Jackson-Stewart
# Ms K Lomas
# Mrs S O’Connor
# Mrs N Ishmael-Georges
# Mrs MJ Fortune
# Mrs D Kerekes
# Mrs D Hooper
# Mr S Thomas
# Mr M Leid
# Mr L Monye
# Mr L Kesner
# page  17
# Mr G Buckle
# Mr E Oyedeji
# Mr DC Sablon
# Mr D Turtle
# Mr D Palmer
# Mr C Claxton
#  Mr B Kenbata
# Mr B Harrison
# Mr A Nickolson
# Miss T Sarwar
# Miss M Kurek
# Mrs J Caparros
# Miss R Kelly
# Miss P Ross
# Mr T Taruvinga
# Miss M Bradberry
# Ms R Lingyte
# Mr W Mohammed
# Mrs Agnes Oke
# Mr I Gasrini
# Mr C Longcroft
#  Mrs H Mahal
#   Ms IL Chand
# Mrs S Henderson
#  Mrs Mary Ann Eyre
#  Mr S Evans and others
#  Mr Robert Wasowski
# Mr R Warrington
# Mr P A Davis
#  Mr Philip Mottershead
#  Mr O Scott
#   Mr L Perry
#  Mr D Connell
#  Mr D Adams
# Mr Craig Taylor and others
#  Miss M Wilson
#  Miss KL Stone
#  Miss J Rostron
# Ms B Mahdavi
# page  123
# Mrs S Haworth
# Mrs D Sanderson
#  Mr T Glenn
# Mr N Moore
# Mr D Baker
# Shirley Russell
# Miss R Akhtar
#   Miss MJ Clynes
# Miss J Critchley
# Miss E Cook
#  Miss B Hoyle
# Miss R Fraser
#  Mr J Carter
#  Ms P McCormick
# Mr R Jeffrey
#  Ms MM Allison
# Mr A MacKay for the late Mrs Shona MacKay
#  Miss L Brannan
# error on case:
# Read the full decision in Mr R Jeffrey v South Lanarkshire Leisure and Culture Ltd:4102459/2014 - Withdrawal.
#
# Mr M Doolan
# Mrs A Clements
# Ms E McDonald
#   Mr S Wallace
# Ms S Lissenden
#  Ms M McMunn
# error on case:
# Read the full decision in Mr I Foreman v Inverclyde Council:104427/2011 - Withdrawal.
#
# Mr JC Peddie on behalf of the late Frances Peddie
# Mrs SJ Layden
#  Mr C L Garrett
# Miss L Napier
# Mr R Ballantyne and others
# Mrs V Wilson
# Ms M McNeilage
#  Mrs A Murray
#  Mrs J Magee
#  Mrs A Craig
# Mrs MR Sutherland
# Mrs J Burns and others
#  Mrs A McGillivray
# Miss V Porter
# Mr D Fincham
# Mr Christopher Stringer
# Mr M Tyson
# Mr S Dobson
# Mr Mark Lawrance
# Mrs S Collins
# Ms F Cooper
# Miss E Ridsdale
# Mr A Ansari
# Mrs N Williams
# page  124

# %%
case_df.to_csv(r'case summary.csv')

# %%
page = requests.get("https://www.gov.uk/employment-tribunal-decisions/ms-c-gray-as-executor-for-ms-gp-simpson-v-north-lanarkshire-council-103476-2007-and-others")
casesoup = BeautifulSoup(page.content, 'html.parser')

casehtml = list(casesoup.children)[4]
casebody = list(casehtml.children)[5]

try:
    case0 = {'CaseNr': [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1]], 
             'Country': [casebody.find_all("dd",class_="app-c-important-metadata__definition")[1].get_text()], 
             'Date': [case.find("time")['datetime']], 
             'Jurisdiction' : [find_jurisdiction(casebody)],
             'Outcome' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('- ')[1].split('.')[0]],
             'Claimant' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[0]],
             'Defendent' : [casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()[27:].split(' v ')[1].split(': ')[0]]}
except:
    print("error on case: ",casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text().split('/20')[0].split(': ')[1] )
# Out:
# error on case:  103476

# %%
casebody.find_all("div", class_="gem-c-govspeak govuk-govspeak direction-ltr")[0].get_text()
# Out:
# '\nRead the full decision in Ms C Gray As Executor for Ms GP Simpson v North Lanarkshire Council: 103476/2007 and Others.\n'
